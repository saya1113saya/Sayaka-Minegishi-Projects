# %% [markdown]
# # Advanced Data Science Capstone Project - Leukemia Image Classification
#
# BY Sayaka Minegishi
# June 2021

# %% [markdown]
# ## Use Case
#
# This project will utilize the Leukemia Dataset uploaded to Kaggle by Nikhil Sharma to make an image classification program that classifies whether a patient has acute lymphoblastic leukemia, given an image of their bone marrow aspirate smear.

# %% [markdown]
# First, we will install the relevant packages

# %%
pip install opencv-python-headless
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.2.54-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 9.6 MB/s eta 0:00:011
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from opencv-python-headless) (1.18.5)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.5.2.54
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: tensorflow in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (3.12.3)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.27.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast==0.2.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Collecting scipy==1.4.1; python_version >= "3"
#   Downloading scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
#      |████████████████████████████████| 26.1 MB 20.4 MB/s eta 0:00:01
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from protobuf>=3.8.0->tensorflow) (47.3.1.post20200622)
# Requirement already satisfied: h5py in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (3.1.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (1.22.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow) (2.24.0)
# Requirement already satisfied: aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.6.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.25.9)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.0.1)
# Requirement already satisfied: multidict<5.0,>=4.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (4.7.6)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (19.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (1.5.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow) (3.7.4.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.5.0
#     Uninstalling scipy-1.5.0:
#       Successfully uninstalled scipy-1.5.0
# Successfully installed scipy-1.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user --upgrade tensorflow
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting tensorflow
#   Downloading tensorflow-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 27 kB/s s eta 0:00:018     |█████████████████▌              | 249.1 MB 41.8 MB/s eta 0:00:05     |██████████████████████          | 311.5 MB 22.4 MB/s eta 0:00:07
# Requirement already satisfied, skipping upgrade: termcolor~=1.1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 38.6 MB/s eta 0:00:01    |█▋                              | 757 kB 38.6 MB/s eta 0:00:01
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting wheel~=0.35
#   Downloading wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (3.12.3)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 7.8 MB/s  eta 0:00:01
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 39.8 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.6 MB/s  eta 0:00:01
# Collecting absl-py~=0.10
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 44.5 MB/s eta 0:00:01
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied, skipping upgrade: typing-extensions~=3.7.4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (3.7.4.2)
# Requirement already satisfied, skipping upgrade: wrapt~=1.12.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.12.1)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 42.8 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 45.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: google-pasta~=0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 45.3 MB/s eta 0:00:01
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 44.8 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: setuptools in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from protobuf>=3.9.2->tensorflow) (47.3.1.post20200622)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (0.4.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 38.8 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 37.9 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (2.24.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (1.22.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Collecting cached-property; python_version < "3.8"
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.9)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.25.9)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2021.5.30)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.6)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied, skipping upgrade: aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (3.6.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.1.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (19.3.0)
# Requirement already satisfied, skipping upgrade: multidict<5.0,>=4.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.6)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (3.0.1)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (1.5.1)
# Installing collected packages: numpy, gast, wheel, astunparse, opt-einsum, keras-nightly, keras-preprocessing, absl-py, flatbuffers, grpcio, tensorflow-estimator, tensorboard-plugin-wit, tensorboard-data-server, tensorboard, cached-property, h5py, tensorflow
#   WARNING: The scripts f2py, f2py3 and f2py3.7 are installed in '/home/wsuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wheel is installed in '/home/wsuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/home/wsuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/home/wsuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed absl-py-0.12.0 astunparse-1.6.3 cached-property-1.5.2 flatbuffers-1.12 gast-0.4.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 numpy-1.19.5 opt-einsum-3.3.0 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 wheel-0.36.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras==2.3.1
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting keras==2.3.1
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 17.7 MB/s eta 0:00:01
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from keras==2.3.1) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/wsuser/.local/lib/python3.7/site-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: pyyaml in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from keras==2.3.1) (5.4.1)
# Requirement already satisfied: h5py in /home/wsuser/.local/lib/python3.7/site-packages (from keras==2.3.1) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /home/wsuser/.local/lib/python3.7/site-packages (from keras==2.3.1) (1.19.5)
# Requirement already satisfied: cached-property; python_version < "3.8" in /home/wsuser/.local/lib/python3.7/site-packages (from h5py->keras==2.3.1) (1.5.2)
# Installing collected packages: keras
# Successfully installed keras-2.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: tensorflow in /home/wsuser/.local/lib/python3.7/site-packages (2.5.0)
# Requirement already satisfied: tensorboard~=2.5 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: gast==0.4.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio~=1.34.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (3.12.3)
# Requirement already satisfied: wrapt~=1.12.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (3.7.4.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: absl-py~=0.10 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: wheel~=0.35 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py~=3.1.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (47.3.1.post20200622)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/wsuser/.local/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (1.22.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow) (0.4.1)
# Requirement already satisfied: cached-property; python_version < "3.8" in /home/wsuser/.local/lib/python3.7/site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (3.6.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (3.0.1)
# Requirement already satisfied: multidict<5.0,>=4.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.6)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (1.5.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (19.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Load Data
#
# We will now download the bone marrow aspirate smear images using IBM Cloud's object storage. The images are all contained in a single folder called 'input' (imported as input.zip), and training and validation sets have already been created for both leukemia-positive and leukemia-negative individuals. 20% of the data for each category has been used for validation.

# %%
import shutil
import os

#delete the directories containing our image files if they are already present
if 'input' in os.listdir("./"):
    shutil.rmtree('input')

if 'input.zip' in os.listdir("./"):
    os.remove('input.zip')

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-62a11686-a522-45e1-9d33-be942e569d01',
    'IBM_API_KEY_ID': 'AyDmNB01z7kaQWR4dCKsn7kmKj5OQ1dQRsDhMpSid0zy',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'coursera-donotdelete-pr-axcazqc6bchxob',
    'FILE': 'input.zip'
}

# %%
from ibm_botocore.client import Config
import ibm_boto3

cos1 = ibm_boto3.client(service_name = 's3', 
                       ibm_api_key_id = credentials_1['IBM_API_KEY_ID'],
                       ibm_service_instance_id = credentials_1['IAM_SERVICE_ID'],
                       ibm_auth_endpoint = credentials_1['IBM_AUTH_ENDPOINT'],
                       config = Config(signature_version='oauth'),
                       endpoint_url = credentials_1['ENDPOINT'])

# %%
#download the zip file containing all files

cos1.download_file(Bucket = credentials_1['BUCKET'], Key = 'input.zip', Filename = 'input.zip')

# %%
#extract the contents of the ALL positive zip file
from zipfile import*
print('Extract all files in input.zip to the current directory')
with ZipFile('input.zip', 'r') as zipObj:
    zipObj.extractall() #extract the contents of the zip file
# Out:
# Extract all files in input.zip to the current directory

# %%
if '__MACOSX' in os.listdir("./"):
    shutil.rmtree("./__MACOSX")

# %%
#check the directory
os.listdir("./")
# Out:
# ['input.zip', 'input', '.virtual_documents']

# %% [markdown]
# ## Initial Data Exploration

# %% [markdown]
# First we will check what files are in our directory.

# %%
#check the leukemia-positive individuals in the training data set
os.listdir("./input/training/positive") #check that the files are in the directory
# Out:
# ['Im105_1.jpg',
#  'Im085_1.jpg',
#  'Im093_1.jpg',
#  'Im065_1.jpg',
#  'Im092_1.jpg',
#  'Im126_1.jpg',
#  'Im030_1.jpg',
#  'Im111_1.jpg',
#  'Im047_1.jpg',
#  'Im101_1.jpg',
#  'Im074_1.jpg',
#  'Im064_1.jpg',
#  'Im224_1.jpg',
#  'Im106_1.jpg',
#  'Im075_1.jpg',
#  'Im035_1.jpg',
#  'Im100_1.jpg',
#  'Im039_1.jpg',
#  'Im046_1.jpg',
#  'Im057_1.jpg',
#  'Im040_1.jpg',
#  'Im082_1.jpg',
#  'Im090_1.jpg',
#  'Im123_1.jpg',
#  'Im038_1.jpg',
#  'Im028_1.jpg',
#  'Im088_1.jpg',
#  'Im084_1.jpg',
#  'Im095_1.jpg',
#  'Im078_1.jpg',
#  'Im070_1.jpg',
#  '.DS_Store',
#  'Im119_1.jpg',
#  'Im048_1.jpg',
#  'Im125_1.jpg',
#  'Im115_1.jpg',
#  'Im077_1.jpg',
#  'Im072_1.jpg',
#  'Im086_1.jpg',
#  'Im118_1.jpg',
#  'Im112_1.jpg',
#  'Im094_1.jpg',
#  'Im076_1.jpg',
#  'Im079_1.jpg',
#  'Im117_1.jpg',
#  'Im052_1.jpg',
#  'Im110_1.jpg',
#  'Im032_1.jpg',
#  'Im050_1.jpg',
#  'Im108_1.jpg',
#  'Im083_1.jpg',
#  'Im130_1.jpg',
#  'Im089_1.jpg',
#  'Im063_1.jpg',
#  'Im113_1.jpg',
#  'Im081_1.jpg',
#  'Im103_1.jpg',
#  'Im114_1.jpg',
#  'Im122_1.jpg',
#  'Im049_1.jpg',
#  'Im102_1.jpg',
#  'Im096_1.jpg',
#  'Im060_1.jpg',
#  'Im069_1.jpg',
#  'Im043_1.jpg',
#  'Im128_1.jpg',
#  'Im058_1.jpg',
#  'Im109_1.jpg',
#  'Im045_1.jpg',
#  'Im223_1.jpg',
#  'Im127_1.jpg',
#  'Im042_1.jpg',
#  'Im051_1.jpg',
#  'Im029_1.jpg',
#  'Im033_1.jpg',
#  'Im120_1.jpg',
#  'Im080_1.jpg',
#  'Im061_1.jpg',
#  'Im121_1.jpg',
#  'Im041_1.jpg',
#  'Im044_1.jpg',
#  'Im059_1.jpg',
#  'Im129_1.jpg',
#  'Im099_1.jpg',
#  'Im054_1.jpg',
#  'Im104_1.jpg',
#  'Im066_1.jpg',
#  'Im097_1.jpg',
#  'Im031_1.jpg',
#  'Im067_1.jpg',
#  'Im087_1.jpg',
#  'Im068_1.jpg',
#  'Im036_1.jpg',
#  'Im073_1.jpg',
#  'Im091_1.jpg',
#  'Im034_1.jpg',
#  'Im107_1.jpg',
#  'Im062_1.jpg',
#  'Im124_1.jpg',
#  'Im071_1.jpg',
#  'Im053_1.jpg',
#  'Im037_1.jpg',
#  'Im222_1.jpg',
#  'Im116_1.jpg',
#  'Im098_1.jpg',
#  'Im055_1.jpg',
#  'Im056_1.jpg']

# %%
#list of leukemia-negative individuals in the training set
print("Leukemia-negative individuals in training data set:")
print(os.listdir("./input/training/negative"))
print()

#list of leukemia-positive individuals in the validation set
print("list of leukemia-positive individuals in the validation set:")
print(os.listdir("./input/validation/positive"))
print()

#list of leukemia-negative individuals in the validation set
print("list of leukemia-negative individuals in the validation set:")
print(os.listdir("./input/validation/negative"))
print()
# Out:
# Leukemia-negative individuals in training data set:
# ['Im258_0.jpg', 'Im102_0.jpg', 'Im144_0.jpg', 'Im240_0.jpg', 'Im214_0.jpg', 'Im246_0.jpg', 'Im205_0.jpg', 'Im254_0.jpg', 'Im161_0.jpg', 'Im250_0.jpg', 'Im233_0.jpg', 'Im255_0.jpg', 'Im174_0.jpg', 'Im132_0.jpg', 'Im134_0.jpg', 'Im163_0.jpg', 'Im107_0.jpg', 'Im166_0.jpg', 'Im095_0.jpg', 'Im158_0.jpg', 'Im135_0.jpg', 'Im248_0.jpg', 'Im238_0.jpg', 'Im101_0.jpg', 'Im165_0.jpg', 'Im162_0.jpg', 'Im213_0.jpg', 'Im259_0.jpg', 'Im108_0.jpg', 'Im142_0.jpg', 'Im131_0.jpg', 'Im100_0.jpg', 'Im186_0.jpg', 'Im235_0.jpg', 'Im251_0.jpg', 'Im260_0.jpg', 'Im227_0.jpg', 'Im173_0.jpg', 'Im223_0.jpg', 'Im243_0.jpg', 'Im160_0.jpg', 'Im203_0.jpg', 'Im181_0.jpg', 'Im207_0.jpg', 'Im159_0.jpg', 'Im234_0.jpg', 'Im182_0.jpg', 'Im149_0.jpg', 'Im245_0.jpg', 'Im150_0.jpg', 'Im216_0.jpg', 'Im098_0.jpg', 'Im137_0.jpg', '.DS_Store', 'Im104_0.jpg', 'Im193_0.jpg', 'Im183_0.jpg', 'Im190_0.jpg', 'Im201_0.jpg', 'Im171_0.jpg', 'Im230_0.jpg', 'Im091_0.jpg', 'Im185_0.jpg', 'Im153_0.jpg', 'Im096_0.jpg', 'Im249_0.jpg', 'Im195_0.jpg', 'Im232_0.jpg', 'Im192_0.jpg', 'Im212_0.jpg', 'Im242_0.jpg', 'Im093_0.jpg', 'Im141_0.jpg', 'Im152_0.jpg', 'Im191_0.jpg', 'Im147_0.jpg', 'Im222_0.jpg', 'Im089_0.jpg', 'Im168_0.jpg', 'Im204_0.jpg', 'Im256_0.jpg', 'Im146_0.jpg', 'Im211_0.jpg', 'Im145_0.jpg', 'Im210_0.jpg', 'Im198_0.jpg', 'Im237_0.jpg', 'Im209_0.jpg', 'Im177_0.jpg', 'Im257_0.jpg', 'Im208_0.jpg', 'Im231_0.jpg', 'Im218_0.jpg', 'Im180_0.jpg', 'Im106_0.jpg', 'Im206_0.jpg', 'Im175_0.jpg', 'Im155_0.jpg', 'Im194_0.jpg', 'Im148_0.jpg', 'Im189_0.jpg', 'Im090_0.jpg', 'Im176_0.jpg', 'Im253_0.jpg', 'Im220_0.jpg', 'Im169_0.jpg', 'Im172_0.jpg', 'Im236_0.jpg', 'Im088_0.jpg', 'Im154_0.jpg', 'Im178_0.jpg', 'Im221_0.jpg', 'Im140_0.jpg', 'Im226_0.jpg', 'Im164_0.jpg', 'Im184_0.jpg', 'Im224_0.jpg', 'Im239_0.jpg', 'Im196_0.jpg', 'Im105_0.jpg', 'Im170_0.jpg', 'Im139_0.jpg', 'Im156_0.jpg', 'Im229_0.jpg', 'Im167_0.jpg', 'Im157_0.jpg', 'Im228_0.jpg', 'Im187_0.jpg', 'Im092_0.jpg', 'Im143_0.jpg', 'Im133_0.jpg', 'Im097_0.jpg', 'Im244_0.jpg', 'Im199_0.jpg', 'Im136_0.jpg', 'Im188_0.jpg', 'Im217_0.jpg', 'Im241_0.jpg', 'Im252_0.jpg', 'Im215_0.jpg', 'Im151_0.jpg', 'Im179_0.jpg', 'Im219_0.jpg', 'Im202_0.jpg', 'Im138_0.jpg', 'Im103_0.jpg', 'Im197_0.jpg', 'Im225_0.jpg', 'Im094_0.jpg', 'Im200_0.jpg', 'Im247_0.jpg', 'Im099_0.jpg']
#
# list of leukemia-positive individuals in the validation set:
# ['Im014_1.jpg', 'Im001_1.jpg', 'Im010_1.jpg', 'Im006_1.jpg', 'Im020_1.jpg', 'Im009_1.jpg', 'Im021_1.jpg', 'Im018_1.jpg', 'Im023_1.jpg', 'Im025_1.jpg', 'Im005_1.jpg', 'Im022_1.jpg', 'Im026_1.jpg', 'Im008_1.jpg', 'Im027_1.jpg', 'Im015_1.jpg', 'Im003_1.jpg', 'Im013_1.jpg', 'Im016_1.jpg', 'Im002_1.jpg', 'Im019_1.jpg', 'Im017_1.jpg', 'Im011_1.jpg', 'Im012_1.jpg', 'Im024_1.jpg', 'Im007_1.jpg', 'Im004_1.jpg']
#
# list of leukemia-negative individuals in the validation set:
# ['Im045_0.jpg', 'Im035_0.jpg', 'Im044_0.jpg', 'Im075_0.jpg', 'Im074_0.jpg', 'Im066_0.jpg', 'Im069_0.jpg', 'Im077_0.jpg', 'Im071_0.jpg', 'Im040_0.jpg', 'Im038_0.jpg', 'Im047_0.jpg', 'Im070_0.jpg', 'Im041_0.jpg', 'Im064_0.jpg', 'Im037_0.jpg', 'Im072_0.jpg', 'Im081_0.jpg', 'Im078_0.jpg', 'Im043_0.jpg', 'Im087_0.jpg', 'Im039_0.jpg', 'Im046_0.jpg', 'Im086_0.jpg', 'Im084_0.jpg', 'Im067_0.jpg', 'Im042_0.jpg', 'Im085_0.jpg', 'Im068_0.jpg', 'Im082_0.jpg', 'Im080_0.jpg', 'Im083_0.jpg', 'Im036_0.jpg', 'Im065_0.jpg', 'Im076_0.jpg', 'Im079_0.jpg', 'Im034_0.jpg', 'Im073_0.jpg']

# %% [markdown]
# We notice that there is a non-image file called '.DS_Store' in the subdirectory containing leukemia-positive individuals in the training data set. We will need to get rid of this in the ETL stage.

# %%
#Check the number of observations in our data
print("The number of leukemia-positive images in our training set is: ", len(os.listdir("./input/training/positive")))
print("The number of leukemia-negative images in our training set is: ", len(os.listdir("./input/training/negative")))
print()
print("The number of leukemia-positive images in our validation set is: ", len(os.listdir("./input/validation/positive")))
print("The number of leukemia-negative images in our validation set is: ", len(os.listdir("./input/validation/negative")))
# Out:
# The number of leukemia-positive images in our training set is:  107
# The number of leukemia-negative images in our training set is:  152
#
# The number of leukemia-positive images in our validation set is:  27
# The number of leukemia-negative images in our validation set is:  38

# %% [markdown]
# We will now check that the image files open properly:

# %%
#examine a leukemia negative image at random from the training set
import PIL
from PIL import Image

ALL_negative_list = [] #make a list to store the image paths for leukemia-negative individuals

#append the file path to the array
for file in os.listdir("./input/training/negative"):
    file = "./input/training/negative/" + file
    ALL_negative_list.append(file)

#examine one of the images from leukemia negative individuals (the 6th image)
PIL.Image.open(ALL_negative_list[5], mode= 'r')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=257x257 at 0x7FC8E130C110>

# %%
#examine a leukemia positive image at random from the training set

ALL_positive_list = []

for file in os.listdir("./input/training/positive"):
    file = "./input/training/positive/" + file
    ALL_positive_list.append(file)

#examine one of the images from leukemia negative individuals (the 6th image)
PIL.Image.open(ALL_positive_list[5], mode= 'r')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=257x257 at 0x7FC8E0D5D390>

# %% [markdown]
# The images seem to appear normally.

# %% [markdown]
# ### Summary for Initial Data Exploration
#
# #### Quality issues
# The dataset contains images of bone marrow aspirate smears from individuals, which depict their lumphocytes.
#
# Originally, the dataset contained one file that was not an image file ('.DS_Store'). Since this program will be an image classification program, I will remove this unnecessary file from the final dataset. There were no missing values or wrong measurements and images in the training set showed properly. All the files are in the the JPEG format.
#
# #### Feature Quality
# Since my dataset is composed of images for classification, feature quality cannot be assessed by numerical measures. However, all images show bone marrow aspirate smears and are thus comparable and relevant to the program.
#
# #### Value Distribution of Data
# The training set contains 152 images from individuals who do not have acute lumphoblastic leukemia and 107 images from individuals who test positive for acute lymphoblastic leukemia. The validation set contains 27 images from leukemia-positive individuals and 38 images from leukemia-neagtive individuals.
#
# The graph visualizing this distribution of data in the training and validation sets is shown below:

# %%
#visualization
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize = (12, 7))
#x values (the categories)
x = ['training positive', 'training negative', 'validation positive', 'validation negative']

#y values
y = [107, 152, 27, 38]

#create a bar plot comparing the number of images in each file
plt.bar(x, y, color = 'blue', width = 0.5)

#define the labels and the title
plt.xlabel("Data category for bone aspirate smear images for leukemia")
plt.ylabel("Number of images")
plt.title("Number of images for each subset of data in leukemia image classification")

plt.show()

# %% [markdown]
# ## Extract, Transform, Load (ETL)

# %% [markdown]
# We remove the '.DS_Store' file from each directory

# %%
#clean data by removing 'DS_Store' file from each directory

for entryname in os.listdir('./input/training/positive'):
    if (entryname == '.DS_Store'):
        os.remove('./input/training/positive/.DS_Store')
        
for entryname in os.listdir('./input/training/negative'):
    if (entryname == '.DS_Store'):
        os.remove('./input/training/negative/.DS_Store')
        
for entryname in os.listdir('./input/validation/positive'):
    if (entryname == '.DS_Store'):
        os.remove('./input/validation/positive/.DS_Store')

for entryname in os.listdir('./input/validation/negative'):
    if (entryname == '.DS_Store'):
        os.remove('./input/training/positive/.DS_Store')

# %% [markdown]
# ### Data Cleansing
# We now check that there are no duplicate images in our dataset

# %%
#For validation and training data, check that there are no duplicates in images from either the leukemia-positive or leukemia-negative lists
#by comparing the length of each list to the number of unique entries.

#check duplicates for leukemia-positive images in the training set

if len(os.listdir("./input/training/positive")) != len(set(os.listdir("./input/training/positive"))):
    print("Duplicate images present in leukemia-positive images in the training set.")
else:
    print("No duplicate images present in leukemia-positive images in the training set.")

print()

#check duplicates for leukemia-negative images in the training set

if len(os.listdir("./input/training/negative")) != len(set(os.listdir("./input/training/negative"))):
    print("Duplicate images present in leukemia-negative images in the training set.")
else:
    print("No duplicate images present in leukemia-negative images in the training set.")

print()

#check duplicates for leukemia-positive images in the validation set

if len(os.listdir("./input/validation/positive")) != len(set(os.listdir("./input/validation/positive"))):
    print("Duplicate images present in leukemia-positive images in the validation set.")
else:
    print("No duplicate images present in leukemia-positive images in the validation set.")
print()

#check duplicates for leukemia-negative images in the validation set

if len(os.listdir("./input/validation/negative")) != len(set(os.listdir("./input/validation/negative"))):
    print("Duplicate images present in leukemia-negative images in the validation set.")
else:
    print("No duplicate images present in leukemia-negative images in the validation set.")

print()
# Out:
# No duplicate images present in leukemia-positive images in the training set.
#
# No duplicate images present in leukemia-negative images in the training set.
#
# No duplicate images present in leukemia-positive images in the validation set.
#
# No duplicate images present in leukemia-negative images in the validation set.

# %% [markdown]
# Every image in the dataset is unique, as checked in the above cell.

# %% [markdown]
# ## Feature Engineering

# %%
import keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report,confusion_matrix
import tensorflow as tf

import cv2

# %%
# ALL_positive = os.listdir('./input/training/positive') #ALL positive images in training data
# ALL_negative = os.listdir('./input/training/negative') #ALL negative images in training data

# path_train_positive = './input/training/positive/'
# path_train_negative = './input/training/negative/'

# %% [markdown]
# Our first step in feature engineering is making a numpy array that can store the image in an array form and its corresponding label (positive or negative for leukemia) in integer form. We will make two of such arrays: one for our training data and one for our validation data. We will first define a function called make_data_array() that can do this job.

# %%
labels = ['positive', 'negative'] #define the classes
img_size = 224
data_directory = "./"

#create a function to get our data

def make_data_array(data_directory):
    data = [] #create an empty (2D) array to store our data with the image in an array and its label 
    for label in labels:
        path = os.path.join(data_directory, label) #get the path to the directory that contains the images from that specific category
        class_number = labels.index(label) #assign a number to the labels and store this as class_number
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert the image to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size))#reshape the images
                data.append([resized_arr, class_number])
            except Exception as e:
                print(e)
        return np.array(data, dtype = object)

# %% [markdown]
# We will now pass in the directory paths for our training and validation data to the make_data_array function, so that for validation and training data separately we can create an array that contains each image in an array form and its label.

# %%
#define our training and validation data arrays that has the image (as an array) and its category as one array
training_data = make_data_array('./input/training')
validation_data = make_data_array('./input/validation')

# %%
#check how the array for our training data looks:
training_data
# Out:
# array([[array([[[149, 124, 111],
#         [152, 126, 113],
#         [148, 125, 111],
#         ...,
#         [158, 144, 135],
#         [159, 146, 137],
#         [161, 148, 139]],
#
#        [[143, 118, 107],
#         [148, 124, 111],
#         [148, 125, 112],
#         ...,
#         [160, 147, 137],
#         [161, 149, 140],
#         [159, 149, 138]],
#
#        [[149, 122, 111],
#         [149, 123, 112],
#         [147, 123, 113],
#         ...,
#         [156, 146, 133],
#         [161, 152, 139],
#         [160, 150, 135]],
#
#        ...,
#
#        [[153, 146, 133],
#         [154, 147, 134],
#         [154, 146, 132],
#         ...,
#         [155, 147, 129],
#         [155, 147, 128],
#         [155, 147, 128]],
#
#        [[154, 146, 135],
#         [154, 146, 135],
#         [155, 147, 136],
#         ...,
#         [156, 146, 128],
#         [157, 146, 128],
#         [155, 146, 129]],
#
#        [[155, 147, 134],
#         [155, 147, 134],
#         [155, 147, 134],
#         ...,
#         [155, 145, 127],
#         [157, 146, 128],
#         [156, 147, 130]]], dtype=uint8),
#         0],
#        [array([[[166, 160, 146],
#         [168, 162, 147],
#         [166, 160, 146],
#         ...,
#         [170, 162, 151],
#         [170, 163, 152],
#         [169, 163, 151]],
#
#        [[165, 160, 141],
#         [168, 163, 144],
#         [170, 164, 148],
#         ...,
#         [169, 162, 151],
#         [168, 162, 150],
#         [168, 161, 151]],
#
#        [[166, 161, 142],
#         [166, 161, 142],
#         [169, 164, 148],
#         ...,
#         [169, 163, 152],
#         [169, 163, 152],
#         [168, 161, 151]],
#
#        ...,
#
#        [[155, 133, 128],
#         [155, 131, 126],
#         [156, 133, 126],
#         ...,
#         [164, 160, 143],
#         [164, 160, 142],
#         [162, 160, 138]],
#
#        [[154, 131, 126],
#         [155, 132, 126],
#         [157, 133, 124],
#         ...,
#         [164, 161, 143],
#         [164, 161, 142],
#         [163, 160, 139]],
#
#        [[155, 131, 119],
#         [156, 132, 120],
#         [158, 133, 120],
#         ...,
#         [163, 161, 143],
#         [162, 161, 141],
#         [163, 161, 140]]], dtype=uint8),
#         0],
#        [array([[[162, 142, 131],
#         [162, 142, 131],
#         [160, 140, 129],
#         ...,
#         [158, 152, 138],
#         [157, 151, 137],
#         [158, 152, 138]],
#
#        [[161, 143, 133],
#         [159, 141, 132],
#         [160, 141, 132],
#         ...,
#         [159, 154, 137],
#         [159, 154, 137],
#         [158, 152, 135]],
#
#        [[157, 138, 133],
#         [158, 139, 134],
#         [159, 140, 134],
#         ...,
#         [158, 156, 134],
#         [157, 153, 132],
#         [157, 154, 133]],
#
#        ...,
#
#        [[155, 151, 139],
#         [158, 152, 140],
#         [160, 154, 140],
#         ...,
#         [147, 103, 136],
#         [144, 103, 132],
#         [141, 101, 129]],
#
#        [[155, 151, 137],
#         [156, 150, 136],
#         [159, 153, 138],
#         ...,
#         [148, 104, 134],
#         [145, 105, 132],
#         [142, 103, 130]],
#
#        [[157, 153, 139],
#         [157, 151, 137],
#         [160, 152, 138],
#         ...,
#         [146, 103, 131],
#         [144, 104, 131],
#         [144, 105, 132]]], dtype=uint8),
#         0],
#        [array([[[129, 102, 107],
#         [128, 110, 110],
#         [126, 110, 110],
#         ...,
#         [129, 116, 135],
#         [131, 122, 137],
#         [135, 129, 141]],
#
#        [[126, 101, 103],
#         [126, 107, 106],
#         [124, 106, 106],
#         ...,
#         [131, 126, 143],
#         [133, 132, 143],
#         [134, 138, 145]],
#
#        [[125, 105, 102],
#         [126, 108, 106],
#         [126, 107, 108],
#         ...,
#         [137, 138, 148],
#         [139, 143, 149],
#         [140, 147, 150]],
#
#        ...,
#
#        [[152, 150, 153],
#         [149, 150, 150],
#         [148, 151, 149],
#         ...,
#         [151, 149, 150],
#         [151, 150, 148],
#         [151, 150, 146]],
#
#        [[150, 148, 151],
#         [149, 149, 149],
#         [148, 150, 149],
#         ...,
#         [153, 149, 153],
#         [153, 150, 149],
#         [152, 149, 148]],
#
#        [[152, 150, 153],
#         [149, 151, 150],
#         [149, 151, 150],
#         ...,
#         [155, 150, 153],
#         [154, 150, 150],
#         [154, 150, 147]]], dtype=uint8),
#         0],
#        [array([[[159, 152, 134],
#         [161, 154, 138],
#         [161, 154, 138],
#         ...,
#         [158, 137, 118],
#         [157, 136, 119],
#         [158, 136, 122]],
#
#        [[159, 153, 137],
#         [158, 154, 134],
#         [158, 153, 134],
#         ...,
#         [156, 135, 118],
#         [155, 134, 119],
#         [156, 135, 121]],
#
#        [[159, 154, 137],
#         [158, 156, 135],
#         [156, 153, 131],
#         ...,
#         [156, 136, 119],
#         [154, 135, 119],
#         [156, 137, 122]],
#
#        ...,
#
#        [[160, 152, 141],
#         [159, 150, 138],
#         [158, 150, 137],
#         ...,
#         [ 67,  82, 129],
#         [ 72,  82, 132],
#         [ 77,  82, 134]],
#
#        [[158, 152, 140],
#         [158, 150, 137],
#         [159, 152, 138],
#         ...,
#         [ 73,  76, 132],
#         [ 78,  77, 132],
#         [ 79,  76, 132]],
#
#        [[157, 151, 137],
#         [158, 152, 138],
#         [159, 154, 139],
#         ...,
#         [ 80,  75, 132],
#         [ 82,  75, 129],
#         [ 83,  75, 128]]], dtype=uint8),
#         0],
#        [array([[[174, 170, 158],
#         [173, 169, 157],
#         [172, 166, 152],
#         ...,
#         [178, 171, 159],
#         [178, 170, 159],
#         [178, 170, 159]],
#
#        [[170, 166, 155],
#         [172, 167, 156],
#         [173, 167, 153],
#         ...,
#         [177, 170, 159],
#         [176, 170, 158],
#         [177, 170, 159]],
#
#        [[166, 163, 151],
#         [170, 166, 155],
#         [173, 168, 156],
#         ...,
#         [176, 171, 160],
#         [175, 169, 158],
#         [175, 169, 158]],
#
#        ...,
#
#        [[169, 163, 157],
#         [169, 164, 156],
#         [169, 167, 157],
#         ...,
#         [162, 150, 141],
#         [165, 153, 144],
#         [166, 154, 147]],
#
#        [[168, 164, 155],
#         [169, 165, 155],
#         [171, 169, 156],
#         ...,
#         [164, 151, 141],
#         [166, 153, 144],
#         [167, 154, 147]],
#
#        [[169, 165, 154],
#         [170, 167, 155],
#         [171, 170, 155],
#         ...,
#         [168, 156, 142],
#         [166, 154, 140],
#         [163, 152, 140]]], dtype=uint8),
#         0],
#        [array([[[147, 149, 147],
#         [149, 150, 146],
#         [146, 135, 119],
#         ...,
#         [154, 154, 146],
#         [153, 152, 139],
#         [133, 122, 115]],
#
#        [[146, 151, 147],
#         [146, 148, 143],
#         [149, 148, 135],
#         ...,
#         [151, 147, 133],
#         [135, 119, 112],
#         [120,  90, 105]],
#
#        [[144, 149, 147],
#         [150, 150, 148],
#         [154, 150, 146],
#         ...,
#         [124, 108, 109],
#         [113,  91, 100],
#         [129, 109, 112]],
#
#        ...,
#
#        [[144, 149, 141],
#         [141, 145, 147],
#         [139, 144, 147],
#         ...,
#         [138, 144, 141],
#         [143, 149, 142],
#         [139, 144, 141]],
#
#        [[139, 146, 141],
#         [137, 138, 144],
#         [137, 146, 148],
#         ...,
#         [137, 148, 134],
#         [138, 144, 142],
#         [138, 147, 145]],
#
#        [[136, 145, 140],
#         [135, 144, 142],
#         [140, 144, 147],
#         ...,
#         [139, 147, 139],
#         [141, 148, 141],
#         [143, 149, 142]]], dtype=uint8),
#         0],
#        [array([[[172, 171, 153],
#         [178, 176, 158],
#         [177, 173, 154],
#         ...,
#         [175, 169, 150],
#         [173, 170, 151],
#         [171, 170, 152]],
#
#        [[172, 170, 155],
#         [173, 171, 156],
#         [172, 172, 155],
#         ...,
#         [178, 175, 156],
#         [174, 173, 154],
#         [171, 169, 152]],
#
#        [[172, 170, 157],
#         [173, 171, 158],
#         [173, 173, 159],
#         ...,
#         [176, 175, 156],
#         [173, 172, 154],
#         [173, 171, 157]],
#
#        ...,
#
#        [[133,  89, 144],
#         [135,  91, 148],
#         [135,  93, 148],
#         ...,
#         [162, 127, 111],
#         [162, 127, 113],
#         [162, 128, 110]],
#
#        [[132,  86, 148],
#         [135,  90, 151],
#         [136,  93, 152],
#         ...,
#         [166, 128, 114],
#         [165, 127, 115],
#         [160, 124, 108]],
#
#        [[128,  83, 148],
#         [129,  84, 149],
#         [132,  90, 153],
#         ...,
#         [162, 124, 112],
#         [162, 124, 113],
#         [160, 123, 107]]], dtype=uint8),
#         0],
#        [array([[[ 78,  21, 116],
#         [ 79,  23, 120],
#         [ 78,  24, 120],
#         ...,
#         [139, 123, 123],
#         [139, 121, 120],
#         [140, 120, 119]],
#
#        [[ 81,  25, 119],
#         [ 81,  25, 120],
#         [ 80,  25, 119],
#         ...,
#         [138, 122, 122],
#         [139, 121, 120],
#         [141, 122, 122]],
#
#        [[ 82,  26, 119],
#         [ 79,  23, 117],
#         [ 85,  24, 121],
#         ...,
#         [140, 122, 125],
#         [138, 120, 124],
#         [139, 120, 129]],
#
#        ...,
#
#        [[143, 120, 133],
#         [141, 108, 129],
#         [137, 104, 126],
#         ...,
#         [139, 118, 119],
#         [139, 116, 119],
#         [139, 116, 119]],
#
#        [[142, 119, 132],
#         [142, 108, 130],
#         [138, 105, 126],
#         ...,
#         [140, 118, 120],
#         [141, 117, 121],
#         [140, 116, 120]],
#
#        [[141, 118, 132],
#         [140, 107, 129],
#         [138, 103, 127],
#         ...,
#         [140, 117, 123],
#         [142, 118, 122],
#         [142, 117, 121]]], dtype=uint8),
#         0],
#        [array([[[174, 171, 156],
#         [176, 173, 158],
#         [175, 172, 157],
#         ...,
#         [180, 177, 164],
#         [179, 175, 163],
#         [180, 176, 164]],
#
#        [[174, 171, 156],
#         [174, 170, 156],
#         [175, 171, 159],
#         ...,
#         [176, 174, 162],
#         [175, 173, 161],
#         [176, 172, 162]],
#
#        [[174, 171, 157],
#         [174, 170, 156],
#         [175, 171, 159],
#         ...,
#         [175, 171, 163],
#         [175, 171, 163],
#         [175, 171, 163]],
#
#        ...,
#
#        [[159, 133, 118],
#         [160, 134, 119],
#         [160, 134, 119],
#         ...,
#         [183, 176, 153],
#         [184, 177, 154],
#         [183, 177, 153]],
#
#        [[159, 133, 116],
#         [159, 133, 116],
#         [159, 133, 117],
#         ...,
#         [183, 178, 157],
#         [183, 178, 157],
#         [181, 176, 156]],
#
#        [[158, 134, 114],
#         [155, 130, 111],
#         [159, 133, 116],
#         ...,
#         [180, 177, 157],
#         [182, 178, 159],
#         [179, 178, 160]]], dtype=uint8),
#         0],
#        [array([[[160, 143, 127],
#         [164, 145, 130],
#         [161, 141, 126],
#         ...,
#         [165, 138, 127],
#         [163, 137, 125],
#         [166, 140, 128]],
#
#        [[162, 145, 127],
#         [159, 142, 123],
#         [160, 142, 124],
#         ...,
#         [162, 140, 126],
#         [164, 143, 127],
#         [163, 142, 125]],
#
#        [[164, 147, 129],
#         [159, 140, 123],
#         [160, 141, 124],
#         ...,
#         [162, 142, 127],
#         [166, 145, 129],
#         [164, 144, 127]],
#
#        ...,
#
#        [[166, 155, 133],
#         [165, 155, 131],
#         [164, 155, 132],
#         ...,
#         [167, 164, 150],
#         [168, 165, 152],
#         [168, 164, 152]],
#
#        [[163, 154, 133],
#         [165, 156, 134],
#         [165, 157, 136],
#         ...,
#         [168, 165, 150],
#         [168, 164, 151],
#         [169, 165, 153]],
#
#        [[164, 157, 138],
#         [164, 157, 138],
#         [164, 157, 139],
#         ...,
#         [168, 165, 150],
#         [169, 165, 153],
#         [169, 165, 153]]], dtype=uint8),
#         0],
#        [array([[[160, 151, 154],
#         [158, 152, 152],
#         [157, 154, 149],
#         ...,
#         [154, 152, 153],
#         [155, 153, 155],
#         [154, 152, 155]],
#
#        [[159, 153, 153],
#         [160, 155, 151],
#         [160, 157, 149],
#         ...,
#         [153, 154, 153],
#         [153, 154, 155],
#         [152, 152, 156]],
#
#        [[160, 155, 153],
#         [161, 158, 153],
#         [162, 160, 152],
#         ...,
#         [153, 155, 152],
#         [150, 154, 152],
#         [149, 153, 155]],
#
#        ...,
#
#        [[119,  99, 112],
#         [121, 100, 117],
#         [124, 103, 121],
#         ...,
#         [152, 153, 148],
#         [152, 153, 148],
#         [151, 152, 147]],
#
#        [[123, 100, 116],
#         [125, 102, 120],
#         [129, 108, 125],
#         ...,
#         [151, 153, 147],
#         [150, 152, 148],
#         [149, 151, 148]],
#
#        [[128, 107, 120],
#         [131, 109, 125],
#         [135, 116, 129],
#         ...,
#         [149, 151, 147],
#         [148, 150, 147],
#         [147, 149, 146]]], dtype=uint8),
#         0],
#        [array([[[133, 110, 119],
#         [135, 110, 114],
#         [134, 111, 114],
#         ...,
#         [138, 108, 116],
#         [136, 110, 115],
#         [135, 110, 114]],
#
#        [[134, 108, 122],
#         [136, 108, 118],
#         [135, 108, 117],
#         ...,
#         [135, 104, 113],
#         [132, 106, 112],
#         [134, 108, 113]],
#
#        [[133, 103, 122],
#         [138, 107, 123],
#         [136, 107, 120],
#         ...,
#         [137, 107, 116],
#         [134, 107, 116],
#         [136, 110, 119]],
#
#        ...,
#
#        [[159, 159, 161],
#         [161, 161, 163],
#         [162, 162, 163],
#         ...,
#         [163, 163, 160],
#         [162, 163, 159],
#         [161, 163, 159]],
#
#        [[158, 158, 159],
#         [159, 160, 160],
#         [162, 161, 163],
#         ...,
#         [162, 164, 159],
#         [161, 165, 158],
#         [160, 165, 158]],
#
#        [[160, 160, 164],
#         [158, 159, 161],
#         [162, 162, 162],
#         ...,
#         [157, 161, 160],
#         [157, 163, 158],
#         [158, 165, 158]]], dtype=uint8),
#         0],
#        [array([[[156, 151, 129],
#         [157, 152, 130],
#         [157, 152, 130],
#         ...,
#         [147, 121, 105],
#         [147, 123, 107],
#         [151, 128, 112]],
#
#        [[156, 152, 129],
#         [156, 152, 130],
#         [154, 150, 128],
#         ...,
#         [147, 122, 105],
#         [150, 124, 108],
#         [151, 126, 109]],
#
#        [[152, 152, 128],
#         [153, 153, 129],
#         [154, 154, 130],
#         ...,
#         [147, 124, 108],
#         [148, 125, 109],
#         [150, 127, 110]],
#
#        ...,
#
#        [[149, 116, 102],
#         [152, 120, 104],
#         [156, 126, 109],
#         ...,
#         [146, 118,  99],
#         [146, 118, 100],
#         [147, 118, 101]],
#
#        [[151, 118, 107],
#         [152, 119, 104],
#         [155, 125, 108],
#         ...,
#         [145, 116, 100],
#         [144, 117, 100],
#         [146, 119, 102]],
#
#        [[149, 120, 106],
#         [150, 119, 103],
#         [150, 120, 104],
#         ...,
#         [145, 117, 101],
#         [144, 117, 100],
#         [145, 118, 101]]], dtype=uint8),
#         0],
#        [array([[[165, 162, 147],
#         [165, 161, 146],
#         [166, 162, 148],
#         ...,
#         [168, 164, 152],
#         [170, 166, 154],
#         [173, 167, 151]],
#
#        [[166, 160, 144],
#         [167, 161, 148],
#         [168, 162, 150],
#         ...,
#         [171, 166, 151],
#         [172, 166, 152],
#         [175, 167, 154]],
#
#        [[167, 161, 145],
#         [168, 162, 148],
#         [168, 162, 150],
#         ...,
#         [172, 165, 150],
#         [172, 165, 150],
#         [176, 168, 155]],
#
#        ...,
#
#        [[158, 139, 128],
#         [162, 140, 128],
#         [162, 139, 127],
#         ...,
#         [103,  89, 142],
#         [107,  88, 144],
#         [110,  86, 146]],
#
#        [[163, 144, 134],
#         [162, 142, 132],
#         [160, 139, 129],
#         ...,
#         [105,  87, 144],
#         [110,  86, 146],
#         [114,  85, 147]],
#
#        [[164, 146, 134],
#         [161, 143, 131],
#         [160, 142, 132],
#         ...,
#         [106,  84, 145],
#         [114,  85, 149],
#         [117,  83, 149]]], dtype=uint8),
#         0],
#        [array([[[122, 107, 104],
#         [124, 111, 103],
#         [128, 111, 107],
#         ...,
#         [159, 160, 155],
#         [158, 159, 154],
#         [159, 160, 155]],
#
#        [[129, 110, 105],
#         [128, 111, 104],
#         [131, 109, 108],
#         ...,
#         [159, 159, 156],
#         [159, 159, 156],
#         [162, 160, 158]],
#
#        [[132, 107, 107],
#         [134, 108, 107],
#         [132, 108, 107],
#         ...,
#         [160, 163, 156],
#         [159, 161, 155],
#         [162, 160, 156]],
#
#        ...,
#
#        [[130, 110, 113],
#         [130, 109, 113],
#         [130, 111, 112],
#         ...,
#         [156, 157, 156],
#         [155, 156, 155],
#         [158, 159, 158]],
#
#        [[131, 111, 113],
#         [131, 111, 113],
#         [133, 113, 115],
#         ...,
#         [159, 159, 157],
#         [159, 160, 156],
#         [160, 161, 157]],
#
#        [[131, 111, 112],
#         [131, 110, 112],
#         [133, 112, 114],
#         ...,
#         [158, 159, 154],
#         [159, 160, 154],
#         [156, 157, 152]]], dtype=uint8),
#         0],
#        [array([[[175, 173, 158],
#         [175, 173, 158],
#         [174, 173, 158],
#         ...,
#         [162, 140, 126],
#         [163, 140, 126],
#         [164, 141, 127]],
#
#        [[178, 176, 161],
#         [177, 175, 160],
#         [175, 173, 158],
#         ...,
#         [162, 137, 126],
#         [163, 138, 127],
#         [166, 139, 130]],
#
#        [[175, 173, 158],
#         [175, 173, 158],
#         [173, 174, 158],
#         ...,
#         [163, 136, 126],
#         [165, 138, 128],
#         [166, 139, 129]],
#
#        ...,
#
#        [[161, 137, 130],
#         [163, 135, 130],
#         [160, 132, 129],
#         ...,
#         [170, 153, 140],
#         [175, 159, 144],
#         [178, 166, 146]],
#
#        [[159, 136, 128],
#         [159, 134, 127],
#         [159, 133, 128],
#         ...,
#         [178, 163, 146],
#         [181, 168, 148],
#         [184, 174, 150]],
#
#        [[159, 136, 131],
#         [158, 133, 128],
#         [159, 134, 130],
#         ...,
#         [184, 172, 153],
#         [188, 177, 156],
#         [193, 183, 158]]], dtype=uint8),
#         0],
#        [array([[[158, 156, 159],
#         [156, 155, 160],
#         [154, 154, 159],
#         ...,
#         [133, 114, 132],
#         [132, 114, 129],
#         [130, 112, 126]],
#
#        [[156, 155, 159],
#         [156, 156, 160],
#         [156, 155, 160],
#         ...,
#         [135, 120, 133],
#         [135, 120, 132],
#         [133, 118, 128]],
#
#        [[154, 156, 161],
#         [156, 158, 162],
#         [156, 157, 162],
#         ...,
#         [140, 134, 136],
#         [134, 131, 134],
#         [133, 131, 134]],
#
#        ...,
#
#        [[152, 153, 156],
#         [151, 155, 158],
#         [152, 157, 159],
#         ...,
#         [158, 154, 161],
#         [158, 156, 160],
#         [158, 156, 159]],
#
#        [[152, 152, 156],
#         [153, 155, 159],
#         [154, 157, 161],
#         ...,
#         [157, 155, 158],
#         [159, 157, 158],
#         [156, 155, 156]],
#
#        [[154, 151, 158],
#         [154, 154, 162],
#         [154, 155, 163],
#         ...,
#         [156, 154, 155],
#         [157, 156, 153],
#         [155, 154, 150]]], dtype=uint8),
#         0],
#        [array([[[162, 165, 158],
#         [165, 168, 157],
#         [166, 169, 158],
#         ...,
#         [163, 160, 155],
#         [164, 160, 157],
#         [168, 163, 162]],
#
#        [[166, 169, 162],
#         [165, 168, 157],
#         [166, 169, 158],
#         ...,
#         [164, 161, 153],
#         [165, 162, 156],
#         [165, 162, 158]],
#
#        [[167, 168, 164],
#         [164, 167, 159],
#         [165, 167, 159],
#         ...,
#         [165, 165, 152],
#         [166, 167, 155],
#         [163, 164, 154]],
#
#        ...,
#
#        [[167, 162, 166],
#         [167, 163, 165],
#         [167, 164, 165],
#         ...,
#         [167, 172, 159],
#         [163, 171, 157],
#         [162, 170, 160]],
#
#        [[167, 162, 167],
#         [166, 162, 163],
#         [167, 163, 164],
#         ...,
#         [167, 170, 155],
#         [164, 168, 151],
#         [165, 168, 153]],
#
#        [[162, 160, 165],
#         [163, 163, 165],
#         [166, 166, 167],
#         ...,
#         [169, 168, 155],
#         [171, 168, 156],
#         [168, 164, 157]]], dtype=uint8),
#         0],
#        [array([[[142, 129, 107],
#         [140, 129, 106],
#         [142, 127, 114],
#         ...,
#         [152, 156, 133],
#         [151, 154, 127],
#         [153, 158, 130]],
#
#        [[148, 145, 126],
#         [145, 130, 109],
#         [143, 130, 115],
#         ...,
#         [153, 157, 132],
#         [153, 156, 134],
#         [152, 157, 131]],
#
#        [[150, 153, 134],
#         [145, 142, 122],
#         [148, 131, 113],
#         ...,
#         [151, 154, 138],
#         [153, 155, 141],
#         [153, 155, 140]],
#
#        ...,
#
#        [[141, 141, 126],
#         [138, 140, 127],
#         [141, 144, 127],
#         ...,
#         [148, 144, 122],
#         [142, 130, 111],
#         [136, 125, 104]],
#
#        [[139, 140, 123],
#         [140, 143, 124],
#         [137, 141, 125],
#         ...,
#         [130, 120,  97],
#         [143, 136, 114],
#         [133, 125, 106]],
#
#        [[138, 146, 117],
#         [143, 142, 122],
#         [138, 141, 121],
#         ...,
#         [141, 124, 106],
#         [131, 123, 101],
#         [139, 126, 106]]], dtype=uint8),
#         0],
#        [array([[[157, 157, 157],
#         [156, 156, 156],
#         [156, 156, 155],
#         ...,
#         [154, 154, 145],
#         [152, 153, 147],
#         [151, 153, 150]],
#
#        [[154, 157, 155],
#         [155, 156, 155],
#         [156, 157, 156],
#         ...,
#         [154, 153, 147],
#         [153, 153, 150],
#         [153, 154, 153]],
#
#        [[152, 156, 152],
#         [154, 158, 155],
#         [155, 159, 155],
#         ...,
#         [154, 155, 154],
#         [154, 154, 158],
#         [155, 153, 164]],
#
#        ...,
#
#        [[129, 111, 106],
#         [130, 109, 111],
#         [132, 111, 115],
#         ...,
#         [151, 151, 147],
#         [150, 149, 150],
#         [149, 147, 152]],
#
#        [[129, 111, 109],
#         [131, 111, 114],
#         [133, 113, 117],
#         ...,
#         [150, 148, 150],
#         [148, 147, 151],
#         [147, 146, 151]],
#
#        [[129, 111, 111],
#         [131, 110, 117],
#         [134, 113, 119],
#         ...,
#         [151, 145, 154],
#         [148, 146, 152],
#         [147, 146, 151]]], dtype=uint8),
#         0],
#        [array([[[167, 140, 129],
#         [167, 140, 129],
#         [167, 140, 129],
#         ...,
#         [170, 167, 152],
#         [170, 167, 152],
#         [171, 165, 151]],
#
#        [[167, 141, 128],
#         [167, 141, 129],
#         [165, 142, 129],
#         ...,
#         [172, 167, 152],
#         [171, 165, 151],
#         [173, 167, 153]],
#
#        [[168, 141, 130],
#         [167, 140, 129],
#         [166, 142, 130],
#         ...,
#         [172, 166, 152],
#         [171, 165, 151],
#         [173, 167, 153]],
#
#        ...,
#
#        [[180, 176, 161],
#         [183, 177, 163],
#         [171, 163, 150],
#         ...,
#         [168, 164, 151],
#         [169, 164, 152],
#         [171, 165, 153]],
#
#        [[178, 174, 158],
#         [181, 174, 159],
#         [172, 165, 151],
#         ...,
#         [170, 164, 148],
#         [170, 164, 149],
#         [171, 165, 151]],
#
#        [[178, 175, 156],
#         [179, 173, 155],
#         [172, 165, 150],
#         ...,
#         [170, 164, 145],
#         [172, 165, 147],
#         [170, 164, 148]]], dtype=uint8),
#         0],
#        [array([[[152, 146, 130],
#         [151, 145, 129],
#         [152, 146, 130],
#         ...,
#         [148, 135, 120],
#         [148, 135, 119],
#         [149, 133, 118]],
#
#        [[149, 145, 128],
#         [149, 146, 128],
#         [150, 147, 128],
#         ...,
#         [148, 134, 123],
#         [149, 135, 124],
#         [150, 134, 121]],
#
#        [[147, 145, 125],
#         [148, 146, 126],
#         [150, 147, 128],
#         ...,
#         [148, 134, 122],
#         [149, 135, 125],
#         [149, 133, 122]],
#
#        ...,
#
#        [[142, 144, 119],
#         [141, 144, 119],
#         [142, 146, 120],
#         ...,
#         [144, 146, 121],
#         [143, 147, 121],
#         [144, 147, 124]],
#
#        [[143, 145, 122],
#         [142, 145, 123],
#         [142, 145, 123],
#         ...,
#         [144, 148, 122],
#         [143, 147, 122],
#         [143, 146, 123]],
#
#        [[140, 142, 120],
#         [141, 143, 122],
#         [141, 144, 124],
#         ...,
#         [145, 148, 123],
#         [144, 148, 123],
#         [144, 146, 124]]], dtype=uint8),
#         0],
#        [array([[[165, 148, 132],
#         [163, 148, 131],
#         [163, 147, 131],
#         ...,
#         [172, 166, 153],
#         [166, 158, 146],
#         [155, 146, 136]],
#
#        [[165, 148, 132],
#         [165, 149, 131],
#         [164, 149, 130],
#         ...,
#         [172, 165, 153],
#         [165, 155, 145],
#         [155, 145, 135]],
#
#        [[166, 148, 133],
#         [164, 147, 132],
#         [164, 147, 131],
#         ...,
#         [171, 163, 153],
#         [163, 154, 145],
#         [155, 142, 134]],
#
#        ...,
#
#        [[161, 136, 125],
#         [159, 139, 125],
#         [158, 140, 125],
#         ...,
#         [164, 162, 145],
#         [164, 162, 144],
#         [164, 162, 144]],
#
#        [[161, 139, 128],
#         [158, 140, 126],
#         [158, 142, 127],
#         ...,
#         [164, 163, 143],
#         [164, 163, 142],
#         [164, 163, 142]],
#
#        [[161, 142, 128],
#         [159, 143, 128],
#         [157, 142, 126],
#         ...,
#         [164, 162, 143],
#         [165, 163, 142],
#         [164, 162, 141]]], dtype=uint8),
#         0],
#        [array([[[157, 162, 158],
#         [155, 158, 157],
#         [157, 158, 158],
#         ...,
#         [148, 124, 137],
#         [147, 127, 135],
#         [146, 130, 133]],
#
#        [[156, 161, 157],
#         [157, 159, 158],
#         [157, 158, 158],
#         ...,
#         [151, 129, 141],
#         [150, 132, 140],
#         [149, 134, 137]],
#
#        [[157, 162, 159],
#         [158, 160, 159],
#         [158, 160, 159],
#         ...,
#         [153, 132, 143],
#         [150, 135, 141],
#         [147, 136, 139]],
#
#        ...,
#
#        [[130, 106, 128],
#         [131, 110, 127],
#         [134, 113, 126],
#         ...,
#         [153, 158, 156],
#         [155, 156, 160],
#         [155, 156, 162]],
#
#        [[130, 106, 128],
#         [127, 106, 122],
#         [131, 111, 122],
#         ...,
#         [152, 157, 154],
#         [152, 154, 158],
#         [153, 153, 160]],
#
#        [[132, 108, 129],
#         [130, 107, 124],
#         [133, 112, 123],
#         ...,
#         [155, 156, 157],
#         [156, 152, 156],
#         [158, 152, 159]]], dtype=uint8),
#         0],
#        [array([[[147, 150, 140],
#         [149, 152, 142],
#         [148, 151, 143],
#         ...,
#         [141, 141, 133],
#         [114,  94, 103],
#         [123, 102, 103]],
#
#        [[149, 151, 146],
#         [146, 148, 144],
#         [149, 151, 146],
#         ...,
#         [123, 112, 119],
#         [115,  99,  97],
#         [124, 108, 103]],
#
#        [[145, 146, 140],
#         [143, 145, 143],
#         [147, 150, 143],
#         ...,
#         [113, 100, 101],
#         [122, 103, 105],
#         [130, 110, 106]],
#
#        ...,
#
#        [[136, 127, 132],
#         [131, 125, 125],
#         [131, 129, 130],
#         ...,
#         [145, 148, 135],
#         [126, 143, 133],
#         [113, 116, 128]],
#
#        [[127, 125, 130],
#         [126, 124, 127],
#         [135, 127, 132],
#         ...,
#         [122, 134, 128],
#         [109, 107, 121],
#         [103,  87, 104]],
#
#        [[118, 112, 119],
#         [123, 119, 117],
#         [120, 117, 120],
#         ...,
#         [107,  90, 114],
#         [107,  94, 103],
#         [111,  93,  97]]], dtype=uint8),
#         0],
#        [array([[[166, 150, 147],
#         [167, 152, 147],
#         [163, 149, 144],
#         ...,
#         [169, 166, 149],
#         [171, 168, 151],
#         [171, 168, 151]],
#
#        [[160, 139, 138],
#         [160, 141, 139],
#         [159, 141, 139],
#         ...,
#         [170, 168, 150],
#         [171, 168, 149],
#         [171, 168, 149]],
#
#        [[154, 129, 127],
#         [154, 131, 130],
#         [158, 136, 135],
#         ...,
#         [169, 167, 148],
#         [169, 167, 148],
#         [169, 167, 148]],
#
#        ...,
#
#        [[175, 164, 163],
#         [173, 166, 159],
#         [172, 167, 157],
#         ...,
#         [164, 140, 125],
#         [166, 138, 127],
#         [167, 139, 128]],
#
#        [[175, 168, 161],
#         [171, 166, 157],
#         [168, 164, 154],
#         ...,
#         [164, 140, 127],
#         [166, 139, 129],
#         [168, 140, 131]],
#
#        [[172, 168, 157],
#         [174, 170, 159],
#         [173, 169, 157],
#         ...,
#         [167, 143, 131],
#         [168, 143, 132],
#         [166, 142, 130]]], dtype=uint8),
#         0],
#        [array([[[163, 159, 147],
#         [167, 163, 150],
#         [168, 165, 150],
#         ...,
#         [170, 164, 152],
#         [169, 163, 151],
#         [169, 163, 151]],
#
#        [[164, 162, 149],
#         [165, 162, 149],
#         [167, 163, 149],
#         ...,
#         [171, 165, 150],
#         [170, 164, 151],
#         [168, 164, 152]],
#
#        [[166, 162, 150],
#         [167, 163, 151],
#         [166, 161, 150],
#         ...,
#         [169, 164, 151],
#         [169, 164, 152],
#         [166, 162, 151]],
#
#        ...,
#
#        [[166, 155, 142],
#         [162, 146, 134],
#         [156, 137, 124],
#         ...,
#         [157, 145, 140],
#         [157, 145, 140],
#         [153, 142, 135]],
#
#        [[168, 157, 146],
#         [165, 150, 139],
#         [162, 143, 131],
#         ...,
#         [155, 136, 132],
#         [157, 139, 134],
#         [155, 137, 131]],
#
#        [[171, 163, 148],
#         [170, 157, 143],
#         [167, 147, 136],
#         ...,
#         [156, 136, 129],
#         [156, 136, 129],
#         [154, 134, 126]]], dtype=uint8),
#         0],
#        [array([[[165, 136, 122],
#         [163, 134, 120],
#         [164, 135, 121],
#         ...,
#         [167, 141, 123],
#         [166, 140, 125],
#         [168, 142, 127]],
#
#        [[163, 134, 120],
#         [163, 134, 119],
#         [165, 136, 121],
#         ...,
#         [167, 141, 127],
#         [168, 142, 128],
#         [168, 142, 128]],
#
#        [[164, 135, 120],
#         [165, 137, 120],
#         [165, 138, 121],
#         ...,
#         [168, 142, 126],
#         [169, 143, 125],
#         [168, 142, 124]],
#
#        ...,
#
#        [[167, 139, 125],
#         [169, 140, 124],
#         [171, 141, 123],
#         ...,
#         [170, 144, 131],
#         [169, 142, 129],
#         [171, 145, 131]],
#
#        [[169, 142, 125],
#         [169, 141, 122],
#         [170, 140, 120],
#         ...,
#         [172, 145, 134],
#         [168, 142, 129],
#         [168, 142, 128]],
#
#        [[171, 145, 127],
#         [170, 143, 122],
#         [169, 143, 120],
#         ...,
#         [173, 147, 134],
#         [170, 144, 129],
#         [169, 143, 128]]], dtype=uint8),
#         0],
#        [array([[[169, 159, 149],
#         [168, 161, 151],
#         [169, 163, 152],
#         ...,
#         [167, 146, 127],
#         [168, 149, 131],
#         [168, 149, 132]],
#
#        [[168, 157, 148],
#         [168, 159, 150],
#         [169, 161, 151],
#         ...,
#         [169, 148, 129],
#         [171, 152, 135],
#         [172, 154, 137]],
#
#        [[168, 156, 145],
#         [168, 159, 148],
#         [169, 161, 149],
#         ...,
#         [168, 147, 132],
#         [169, 151, 134],
#         [175, 160, 142]],
#
#        ...,
#
#        [[170, 167, 149],
#         [169, 167, 148],
#         [168, 166, 149],
#         ...,
#         [162, 159, 140],
#         [161, 157, 139],
#         [162, 157, 140]],
#
#        [[169, 168, 150],
#         [169, 167, 151],
#         [167, 165, 150],
#         ...,
#         [163, 159, 137],
#         [162, 158, 136],
#         [162, 158, 136]],
#
#        [[166, 164, 149],
#         [166, 164, 151],
#         [166, 163, 151],
#         ...,
#         [164, 159, 139],
#         [162, 156, 136],
#         [161, 156, 136]]], dtype=uint8),
#         0],
#        [array([[[121, 104, 110],
#         [121, 105, 108],
#         [121, 104, 106],
#         ...,
#         [159, 159, 156],
#         [159, 158, 156],
#         [158, 157, 154]],
#
#        [[126, 105, 113],
#         [126, 107, 112],
#         [123, 105, 106],
#         ...,
#         [157, 157, 152],
#         [156, 158, 151],
#         [155, 157, 149]],
#
#        [[127, 106, 117],
#         [127, 107, 114],
#         [123, 105, 110],
#         ...,
#         [159, 159, 158],
#         [159, 159, 157],
#         [158, 159, 155]],
#
#        ...,
#
#        [[158, 160, 157],
#         [157, 159, 156],
#         [154, 157, 154],
#         ...,
#         [132, 122, 138],
#         [130, 118, 134],
#         [129, 117, 133]],
#
#        [[159, 160, 158],
#         [157, 158, 156],
#         [155, 157, 155],
#         ...,
#         [137, 131, 146],
#         [133, 125, 140],
#         [131, 118, 135]],
#
#        [[160, 160, 158],
#         [157, 157, 154],
#         [155, 156, 154],
#         ...,
#         [145, 141, 155],
#         [142, 136, 151],
#         [138, 128, 145]]], dtype=uint8),
#         0],
#        [array([[[164, 151, 142],
#         [165, 151, 142],
#         [170, 157, 146],
#         ...,
#         [ 82,  68, 141],
#         [ 97,  84, 144],
#         [119, 107, 151]],
#
#        [[167, 152, 141],
#         [170, 153, 144],
#         [170, 154, 144],
#         ...,
#         [ 73,  57, 138],
#         [ 85,  72, 142],
#         [105,  94, 148]],
#
#        [[168, 154, 139],
#         [168, 153, 140],
#         [168, 152, 140],
#         ...,
#         [ 73,  54, 139],
#         [ 80,  65, 140],
#         [ 94,  81, 143]],
#
#        ...,
#
#        [[168, 161, 146],
#         [168, 160, 146],
#         [166, 159, 144],
#         ...,
#         [163, 146, 130],
#         [162, 145, 130],
#         [161, 144, 131]],
#
#        [[167, 162, 144],
#         [168, 161, 146],
#         [167, 160, 146],
#         ...,
#         [169, 153, 137],
#         [168, 152, 137],
#         [164, 146, 136]],
#
#        [[167, 162, 142],
#         [167, 160, 142],
#         [165, 159, 144],
#         ...,
#         [174, 158, 143],
#         [174, 160, 145],
#         [168, 154, 143]]], dtype=uint8),
#         0],
#        [array([[[147, 138, 121],
#         [142, 128, 105],
#         [140, 135, 115],
#         ...,
#         [146, 133, 112],
#         [149, 138, 120],
#         [150, 140, 129]],
#
#        [[149, 139, 126],
#         [146, 133, 116],
#         [142, 130, 112],
#         ...,
#         [147, 154, 137],
#         [145, 135, 120],
#         [149, 133, 118]],
#
#        [[149, 144, 124],
#         [147, 130, 121],
#         [139, 127, 111],
#         ...,
#         [151, 154, 137],
#         [153, 155, 142],
#         [150, 156, 126]],
#
#        ...,
#
#        [[140, 136, 124],
#         [147, 147, 139],
#         [143, 143, 127],
#         ...,
#         [140, 123, 105],
#         [141, 129, 104],
#         [139, 126, 107]],
#
#        [[141, 138, 129],
#         [143, 142, 128],
#         [137, 141, 126],
#         ...,
#         [141, 128, 109],
#         [142, 126, 110],
#         [137, 127, 106]],
#
#        [[141, 134, 128],
#         [140, 141, 127],
#         [145, 144, 126],
#         ...,
#         [137, 124, 108],
#         [136, 125, 103],
#         [140, 134, 108]]], dtype=uint8),
#         0],
#        [array([[[124,  77, 147],
#         [119,  76, 145],
#         [118,  76, 147],
#         ...,
#         [164, 138, 123],
#         [166, 142, 125],
#         [163, 140, 122]],
#
#        [[124,  77, 147],
#         [123,  78, 146],
#         [121,  77, 146],
#         ...,
#         [163, 136, 124],
#         [164, 140, 125],
#         [164, 140, 125]],
#
#        [[123,  77, 146],
#         [122,  77, 144],
#         [120,  76, 144],
#         ...,
#         [163, 136, 125],
#         [164, 138, 127],
#         [163, 138, 126]],
#
#        ...,
#
#        [[168, 164, 152],
#         [169, 165, 150],
#         [168, 165, 149],
#         ...,
#         [174, 168, 154],
#         [171, 165, 153],
#         [171, 165, 153]],
#
#        [[167, 165, 150],
#         [169, 166, 151],
#         [169, 166, 150],
#         ...,
#         [173, 167, 154],
#         [170, 164, 152],
#         [172, 165, 154]],
#
#        [[168, 166, 151],
#         [169, 166, 152],
#         [168, 166, 150],
#         ...,
#         [168, 164, 152],
#         [170, 165, 151],
#         [172, 166, 152]]], dtype=uint8),
#         0],
#        [array([[[159, 157, 144],
#         [162, 160, 146],
#         [162, 160, 145],
#         ...,
#         [158, 138, 124],
#         [159, 140, 125],
#         [160, 142, 129]],
#
#        [[160, 158, 145],
#         [161, 159, 146],
#         [160, 158, 144],
#         ...,
#         [160, 138, 120],
#         [161, 140, 120],
#         [161, 141, 123]],
#
#        [[158, 156, 143],
#         [160, 158, 144],
#         [159, 157, 142],
#         ...,
#         [160, 139, 118],
#         [160, 139, 119],
#         [162, 142, 123]],
#
#        ...,
#
#        [[157, 137, 118],
#         [157, 137, 118],
#         [159, 138, 119],
#         ...,
#         [162, 157, 137],
#         [161, 156, 136],
#         [162, 156, 136]],
#
#        [[157, 136, 119],
#         [157, 137, 119],
#         [160, 139, 121],
#         ...,
#         [161, 156, 137],
#         [161, 155, 136],
#         [161, 156, 137]],
#
#        [[157, 134, 120],
#         [157, 134, 120],
#         [159, 136, 122],
#         ...,
#         [162, 158, 138],
#         [160, 155, 136],
#         [160, 157, 138]]], dtype=uint8),
#         0],
#        [array([[[160, 154, 138],
#         [160, 155, 138],
#         [156, 154, 135],
#         ...,
#         [113,  71, 139],
#         [114,  71, 140],
#         [110,  66, 137]],
#
#        [[157, 153, 134],
#         [158, 154, 135],
#         [155, 155, 136],
#         ...,
#         [115,  71, 140],
#         [116,  71, 140],
#         [112,  67, 138]],
#
#        [[155, 153, 133],
#         [156, 154, 134],
#         [154, 155, 133],
#         ...,
#         [115,  73, 140],
#         [114,  72, 138],
#         [112,  71, 137]],
#
#        ...,
#
#        [[145, 135, 118],
#         [152, 143, 126],
#         [154, 149, 130],
#         ...,
#         [119,  85, 133],
#         [118,  84, 134],
#         [116,  84, 134]],
#
#        [[143, 134, 118],
#         [152, 144, 128],
#         [157, 151, 132],
#         ...,
#         [117,  84, 134],
#         [115,  82, 134],
#         [111,  81, 134]],
#
#        [[146, 136, 124],
#         [153, 144, 131],
#         [157, 150, 134],
#         ...,
#         [116,  82, 134],
#         [114,  81, 135],
#         [108,  77, 134]]], dtype=uint8),
#         0],
#        [array([[[154, 156, 150],
#         [152, 154, 149],
#         [154, 154, 150],
#         ...,
#         [131, 107, 125],
#         [135, 114, 130],
#         [139, 123, 134]],
#
#        [[151, 153, 148],
#         [150, 151, 149],
#         [154, 151, 154],
#         ...,
#         [137, 114, 132],
#         [142, 123, 136],
#         [143, 130, 139]],
#
#        [[152, 152, 151],
#         [152, 152, 153],
#         [154, 153, 156],
#         ...,
#         [140, 121, 135],
#         [146, 131, 140],
#         [150, 138, 142]],
#
#        ...,
#
#        [[149, 149, 152],
#         [147, 148, 153],
#         [147, 148, 151],
#         ...,
#         [151, 149, 155],
#         [152, 149, 156],
#         [150, 147, 153]],
#
#        [[151, 150, 153],
#         [149, 150, 152],
#         [148, 150, 150],
#         ...,
#         [150, 147, 154],
#         [152, 150, 156],
#         [147, 145, 151]],
#
#        [[151, 149, 150],
#         [147, 148, 148],
#         [148, 151, 149],
#         ...,
#         [146, 145, 151],
#         [151, 151, 156],
#         [150, 150, 155]]], dtype=uint8),
#         0],
#        [array([[[159, 137, 124],
#         [161, 140, 126],
#         [161, 142, 128],
#         ...,
#         [154, 122, 125],
#         [154, 121, 124],
#         [151, 120, 118]],
#
#        [[161, 139, 124],
#         [162, 140, 125],
#         [162, 140, 125],
#         ...,
#         [156, 120, 123],
#         [157, 120, 124],
#         [150, 116, 115]],
#
#        [[163, 139, 123],
#         [163, 139, 123],
#         [164, 139, 124],
#         ...,
#         [158, 120, 121],
#         [159, 121, 122],
#         [151, 117, 116]],
#
#        ...,
#
#        [[156, 133, 128],
#         [156, 134, 129],
#         [157, 137, 130],
#         ...,
#         [158, 128, 118],
#         [158, 128, 120],
#         [158, 127, 121]],
#
#        [[157, 133, 129],
#         [156, 133, 128],
#         [157, 138, 129],
#         ...,
#         [156, 127, 118],
#         [157, 128, 120],
#         [156, 127, 121]],
#
#        [[156, 131, 127],
#         [158, 133, 128],
#         [158, 135, 127],
#         ...,
#         [157, 128, 121],
#         [157, 128, 122],
#         [156, 127, 121]]], dtype=uint8),
#         0],
#        [array([[[112,  48, 135],
#         [111,  48, 135],
#         [106,  47, 132],
#         ...,
#         [164, 157, 138],
#         [162, 155, 136],
#         [159, 154, 134]],
#
#        [[111,  53, 134],
#         [109,  51, 132],
#         [105,  48, 130],
#         ...,
#         [164, 158, 140],
#         [162, 158, 139],
#         [163, 158, 139]],
#
#        [[110,  56, 133],
#         [112,  57, 135],
#         [111,  57, 134],
#         ...,
#         [163, 159, 141],
#         [162, 159, 140],
#         [162, 160, 141]],
#
#        ...,
#
#        [[162, 143, 127],
#         [158, 139, 123],
#         [158, 139, 123],
#         ...,
#         [158, 141, 128],
#         [159, 141, 128],
#         [159, 142, 128]],
#
#        [[162, 144, 124],
#         [160, 142, 123],
#         [160, 141, 124],
#         ...,
#         [161, 143, 132],
#         [159, 141, 129],
#         [158, 140, 128]],
#
#        [[159, 142, 122],
#         [160, 143, 124],
#         [161, 144, 127],
#         ...,
#         [159, 142, 127],
#         [160, 143, 128],
#         [160, 143, 127]]], dtype=uint8),
#         0],
#        [array([[[167, 145, 129],
#         [165, 142, 128],
#         [166, 143, 128],
#         ...,
#         [ 98,  72, 148],
#         [103,  73, 152],
#         [106,  73, 154]],
#
#        [[167, 142, 129],
#         [167, 141, 130],
#         [168, 143, 130],
#         ...,
#         [105,  84, 147],
#         [105,  81, 149],
#         [106,  77, 148]],
#
#        [[164, 144, 130],
#         [164, 145, 131],
#         [163, 143, 130],
#         ...,
#         [124, 107, 143],
#         [119, 100, 144],
#         [114,  90, 142]],
#
#        ...,
#
#        [[165, 146, 126],
#         [165, 145, 126],
#         [166, 146, 127],
#         ...,
#         [170, 144, 130],
#         [166, 143, 128],
#         [165, 142, 127]],
#
#        [[165, 147, 128],
#         [164, 147, 127],
#         [165, 146, 128],
#         ...,
#         [171, 145, 130],
#         [167, 143, 126],
#         [164, 141, 123]],
#
#        [[167, 148, 130],
#         [165, 147, 127],
#         [165, 146, 127],
#         ...,
#         [170, 144, 129],
#         [167, 143, 126],
#         [166, 143, 125]]], dtype=uint8),
#         0],
#        [array([[[159, 136, 128],
#         [160, 135, 128],
#         [161, 137, 129],
#         ...,
#         [159, 149, 132],
#         [161, 146, 130],
#         [157, 138, 123]],
#
#        [[157, 134, 126],
#         [159, 134, 127],
#         [161, 136, 129],
#         ...,
#         [158, 149, 128],
#         [157, 143, 123],
#         [153, 134, 116]],
#
#        [[158, 137, 125],
#         [160, 136, 128],
#         [161, 136, 128],
#         ...,
#         [158, 146, 124],
#         [158, 142, 121],
#         [148, 128, 108]],
#
#        ...,
#
#        [[165, 154, 133],
#         [167, 160, 138],
#         [167, 161, 141],
#         ...,
#         [153, 126, 113],
#         [154, 127, 116],
#         [152, 126, 115]],
#
#        [[167, 159, 136],
#         [166, 159, 137],
#         [165, 160, 140],
#         ...,
#         [154, 127, 117],
#         [154, 127, 118],
#         [153, 126, 118]],
#
#        [[165, 157, 136],
#         [163, 156, 137],
#         [164, 159, 140],
#         ...,
#         [155, 127, 117],
#         [154, 125, 117],
#         [154, 125, 119]]], dtype=uint8),
#         0],
#        [array([[[156, 137, 126],
#         [157, 137, 126],
#         [160, 140, 129],
#         ...,
#         [161, 144, 131],
#         [162, 144, 132],
#         [163, 145, 133]],
#
#        [[155, 135, 124],
#         [157, 137, 126],
#         [161, 141, 129],
#         ...,
#         [160, 144, 131],
#         [161, 144, 130],
#         [161, 143, 129]],
#
#        [[158, 138, 126],
#         [158, 139, 125],
#         [160, 141, 126],
#         ...,
#         [158, 145, 130],
#         [161, 147, 132],
#         [162, 147, 132]],
#
#        ...,
#
#        [[104,  63, 135],
#         [103,  64, 134],
#         [106,  69, 135],
#         ...,
#         [157, 143, 133],
#         [154, 140, 130],
#         [156, 141, 131]],
#
#        [[106,  63, 134],
#         [107,  66, 134],
#         [110,  71, 135],
#         ...,
#         [156, 142, 130],
#         [156, 142, 129],
#         [157, 143, 130]],
#
#        [[105,  62, 133],
#         [106,  66, 133],
#         [109,  71, 134],
#         ...,
#         [156, 142, 126],
#         [161, 149, 132],
#         [159, 148, 130]]], dtype=uint8),
#         0],
#        [array([[[169, 161, 148],
#         [169, 162, 149],
#         [166, 160, 148],
#         ...,
#         [159, 131, 115],
#         [160, 131, 115],
#         [160, 131, 116]],
#
#        [[170, 163, 150],
#         [170, 164, 150],
#         [169, 163, 150],
#         ...,
#         [159, 133, 113],
#         [159, 132, 113],
#         [158, 131, 114]],
#
#        [[168, 163, 149],
#         [168, 164, 150],
#         [167, 163, 151],
#         ...,
#         [159, 134, 114],
#         [159, 134, 114],
#         [156, 134, 113]],
#
#        ...,
#
#        [[156, 131, 127],
#         [158, 132, 128],
#         [159, 130, 127],
#         ...,
#         [165, 160, 140],
#         [163, 159, 138],
#         [165, 160, 139]],
#
#        [[154, 130, 127],
#         [156, 130, 128],
#         [157, 129, 125],
#         ...,
#         [168, 162, 143],
#         [166, 161, 142],
#         [165, 160, 140]],
#
#        [[153, 129, 125],
#         [155, 129, 125],
#         [157, 129, 124],
#         ...,
#         [171, 167, 147],
#         [171, 166, 146],
#         [165, 163, 142]]], dtype=uint8),
#         0],
#        [array([[[161, 156, 137],
#         [162, 155, 138],
#         [162, 156, 140],
#         ...,
#         [159, 138, 121],
#         [161, 143, 127],
#         [163, 150, 133]],
#
#        [[159, 155, 135],
#         [161, 156, 136],
#         [160, 155, 137],
#         ...,
#         [162, 144, 128],
#         [162, 148, 131],
#         [162, 153, 136]],
#
#        [[158, 155, 134],
#         [160, 155, 135],
#         [160, 155, 137],
#         ...,
#         [164, 149, 133],
#         [164, 151, 136],
#         [162, 153, 140]],
#
#        ...,
#
#        [[150, 134, 118],
#         [150, 135, 120],
#         [153, 136, 122],
#         ...,
#         [152, 140, 123],
#         [155, 146, 129],
#         [158, 151, 133]],
#
#        [[153, 137, 121],
#         [153, 137, 121],
#         [152, 135, 120],
#         ...,
#         [153, 144, 127],
#         [156, 149, 132],
#         [156, 149, 133]],
#
#        [[155, 140, 121],
#         [154, 137, 119],
#         [150, 133, 116],
#         ...,
#         [153, 144, 127],
#         [155, 148, 132],
#         [157, 150, 135]]], dtype=uint8),
#         0],
#        [array([[[140, 124, 103],
#         [140, 125, 107],
#         [137, 124, 105],
#         ...,
#         [143, 124, 115],
#         [145, 147, 132],
#         [140, 142, 124]],
#
#        [[140, 131, 113],
#         [143, 132, 114],
#         [143, 135, 114],
#         ...,
#         [143, 121, 107],
#         [155, 152, 138],
#         [143, 132, 106]],
#
#        [[143, 133, 117],
#         [142, 137, 117],
#         [143, 138, 121],
#         ...,
#         [145, 123, 107],
#         [149, 137, 121],
#         [142, 127, 106]],
#
#        ...,
#
#        [[132, 124, 113],
#         [135, 124, 114],
#         [131, 122, 106],
#         ...,
#         [136, 140, 117],
#         [138, 137, 109],
#         [138, 128, 103]],
#
#        [[133, 124, 112],
#         [132, 127, 117],
#         [134, 130, 118],
#         ...,
#         [138, 140, 116],
#         [139, 141, 119],
#         [137, 137, 114]],
#
#        [[136, 127, 110],
#         [134, 131, 116],
#         [134, 127, 109],
#         ...,
#         [137, 140, 109],
#         [137, 141, 114],
#         [140, 139, 118]]], dtype=uint8),
#         0],
#        [array([[[159, 151, 130],
#         [157, 149, 127],
#         [157, 147, 124],
#         ...,
#         [156, 135, 124],
#         [159, 137, 126],
#         [157, 137, 126]],
#
#        [[161, 157, 136],
#         [159, 155, 133],
#         [157, 152, 129],
#         ...,
#         [157, 136, 125],
#         [157, 137, 125],
#         [155, 135, 124]],
#
#        [[160, 159, 141],
#         [160, 159, 141],
#         [160, 159, 138],
#         ...,
#         [154, 136, 124],
#         [153, 137, 124],
#         [153, 137, 122]],
#
#        ...,
#
#        [[160, 141, 132],
#         [160, 142, 134],
#         [159, 141, 134],
#         ...,
#         [156, 136, 124],
#         [158, 139, 127],
#         [159, 142, 129]],
#
#        [[160, 141, 136],
#         [160, 141, 137],
#         [160, 142, 137],
#         ...,
#         [161, 140, 129],
#         [163, 141, 130],
#         [159, 140, 128]],
#
#        [[158, 139, 133],
#         [160, 141, 135],
#         [156, 137, 131],
#         ...,
#         [158, 139, 125],
#         [158, 138, 125],
#         [160, 141, 127]]], dtype=uint8),
#         0],
#        [array([[[137, 127, 124],
#         [135, 124, 122],
#         [134, 122, 114],
#         ...,
#         [148, 149, 147],
#         [145, 147, 142],
#         [145, 151, 139]],
#
#        [[139, 125, 123],
#         [137, 121, 125],
#         [134, 128, 120],
#         ...,
#         [148, 150, 139],
# ...
#         [152, 156, 138],
#         [151, 153, 137]],
#
#        [[118,  90, 100],
#         [117,  87,  99],
#         [118,  89, 101],
#         ...,
#         [152, 149, 136],
#         [150, 148, 135],
#         [149, 146, 134]],
#
#        [[116,  88, 100],
#         [118,  89, 102],
#         [119,  89, 102],
#         ...,
#         [151, 144, 134],
#         [147, 142, 131],
#         [147, 140, 130]]], dtype=uint8),
#         0],
#        [array([[[162, 162, 162],
#         [161, 162, 162],
#         [161, 161, 161],
#         ...,
#         [156, 158, 157],
#         [156, 158, 157],
#         [156, 158, 157]],
#
#        [[159, 161, 159],
#         [160, 161, 160],
#         [161, 161, 160],
#         ...,
#         [157, 159, 158],
#         [157, 159, 158],
#         [157, 159, 158]],
#
#        [[160, 162, 158],
#         [161, 163, 160],
#         [161, 164, 162],
#         ...,
#         [158, 160, 159],
#         [157, 160, 159],
#         [157, 160, 159]],
#
#        ...,
#
#        [[128,  98, 108],
#         [129,  99, 108],
#         [129,  98, 107],
#         ...,
#         [161, 168, 154],
#         [157, 162, 150],
#         [154, 155, 149]],
#
#        [[129,  99, 107],
#         [129, 101, 106],
#         [128, 100, 105],
#         ...,
#         [158, 165, 149],
#         [154, 158, 146],
#         [151, 151, 145]],
#
#        [[128, 101, 106],
#         [130, 103, 109],
#         [129, 102, 107],
#         ...,
#         [159, 164, 148],
#         [154, 157, 145],
#         [149, 149, 143]]], dtype=uint8),
#         0],
#        [array([[[145, 150, 146],
#         [146, 151, 147],
#         [146, 150, 147],
#         ...,
#         [139, 120, 123],
#         [141, 123, 129],
#         [143, 126, 132]],
#
#        [[147, 152, 148],
#         [147, 152, 148],
#         [147, 152, 149],
#         ...,
#         [141, 123, 124],
#         [142, 125, 127],
#         [144, 128, 130]],
#
#        [[149, 151, 148],
#         [150, 152, 148],
#         [150, 152, 149],
#         ...,
#         [140, 123, 121],
#         [141, 126, 123],
#         [144, 129, 126]],
#
#        ...,
#
#        [[152, 154, 153],
#         [150, 152, 151],
#         [152, 152, 154],
#         ...,
#         [150, 155, 152],
#         [148, 153, 150],
#         [148, 153, 149]],
#
#        [[151, 153, 152],
#         [149, 151, 151],
#         [150, 150, 153],
#         ...,
#         [152, 155, 151],
#         [152, 156, 152],
#         [149, 154, 150]],
#
#        [[150, 152, 151],
#         [148, 149, 151],
#         [149, 149, 152],
#         ...,
#         [151, 154, 151],
#         [153, 155, 153],
#         [152, 154, 153]]], dtype=uint8),
#         0],
#        [array([[[157, 153, 133],
#         [154, 152, 131],
#         [155, 153, 132],
#         ...,
#         [159, 145, 133],
#         [156, 143, 132],
#         [155, 143, 131]],
#
#        [[155, 150, 131],
#         [155, 152, 132],
#         [156, 153, 132],
#         ...,
#         [159, 145, 136],
#         [157, 144, 135],
#         [156, 143, 134]],
#
#        [[155, 150, 131],
#         [155, 150, 131],
#         [157, 151, 132],
#         ...,
#         [158, 144, 136],
#         [156, 143, 135],
#         [155, 142, 134]],
#
#        ...,
#
#        [[157, 148, 138],
#         [155, 149, 137],
#         [153, 148, 136],
#         ...,
#         [106,  62, 126],
#         [105,  63, 126],
#         [105,  63, 127]],
#
#        [[157, 150, 139],
#         [154, 150, 138],
#         [152, 148, 135],
#         ...,
#         [107,  63, 126],
#         [107,  63, 126],
#         [104,  60, 124]],
#
#        [[155, 149, 135],
#         [154, 151, 136],
#         [152, 149, 134],
#         ...,
#         [107,  61, 124],
#         [106,  62, 123],
#         [103,  59, 120]]], dtype=uint8),
#         0],
#        [array([[[151, 147, 146],
#         [149, 146, 150],
#         [149, 144, 150],
#         ...,
#         [140, 126, 126],
#         [140, 126, 125],
#         [140, 124, 124]],
#
#        [[150, 149, 147],
#         [152, 147, 151],
#         [151, 145, 150],
#         ...,
#         [138, 122, 124],
#         [137, 122, 123],
#         [136, 121, 122]],
#
#        [[152, 151, 149],
#         [151, 147, 149],
#         [150, 145, 149],
#         ...,
#         [135, 118, 122],
#         [136, 118, 123],
#         [136, 118, 123]],
#
#        ...,
#
#        [[125, 107, 107],
#         [122, 102, 102],
#         [123, 103, 104],
#         ...,
#         [ 85,  48, 124],
#         [ 77,  34, 113],
#         [ 85,  37, 120]],
#
#        [[127, 107, 106],
#         [126, 106, 105],
#         [124, 103, 105],
#         ...,
#         [ 89,  57, 128],
#         [ 79,  40, 117],
#         [ 88,  42, 125]],
#
#        [[126, 102, 105],
#         [130, 105, 111],
#         [129, 104, 110],
#         ...,
#         [106,  93, 137],
#         [ 95,  80, 127],
#         [ 88,  66, 123]]], dtype=uint8),
#         0],
#        [array([[[148, 136, 122],
#         [150, 138, 126],
#         [150, 137, 128],
#         ...,
#         [148, 141, 123],
#         [149, 142, 124],
#         [151, 145, 123]],
#
#        [[145, 135, 124],
#         [147, 137, 127],
#         [146, 137, 127],
#         ...,
#         [151, 145, 126],
#         [153, 146, 127],
#         [154, 148, 126]],
#
#        [[149, 140, 130],
#         [148, 139, 129],
#         [146, 137, 128],
#         ...,
#         [151, 145, 125],
#         [153, 146, 126],
#         [153, 147, 126]],
#
#        ...,
#
#        [[136, 123, 113],
#         [136, 124, 112],
#         [136, 125, 112],
#         ...,
#         [146, 135, 121],
#         [148, 132, 121],
#         [148, 126, 119]],
#
#        [[135, 118, 106],
#         [135, 119, 107],
#         [131, 118, 103],
#         ...,
#         [147, 138, 118],
#         [149, 135, 118],
#         [149, 132, 117]],
#
#        [[137, 115,  95],
#         [141, 119,  99],
#         [137, 116,  98],
#         ...,
#         [147, 141, 118],
#         [147, 139, 116],
#         [150, 139, 117]]], dtype=uint8),
#         0],
#        [array([[[153, 156, 135],
#         [152, 155, 136],
#         [154, 157, 140],
#         ...,
#         [156, 162, 143],
#         [150, 148, 126],
#         [154, 150, 133]],
#
#        [[151, 154, 137],
#         [156, 160, 141],
#         [154, 159, 139],
#         ...,
#         [158, 161, 146],
#         [151, 155, 130],
#         [156, 149, 135]],
#
#        [[156, 159, 140],
#         [154, 156, 141],
#         [156, 158, 140],
#         ...,
#         [158, 161, 144],
#         [159, 162, 145],
#         [159, 149, 142]],
#
#        ...,
#
#        [[139, 133, 115],
#         [153, 151, 137],
#         [142, 129, 122],
#         ...,
#         [142, 131, 111],
#         [145, 135, 111],
#         [147, 137, 113]],
#
#        [[138, 132, 116],
#         [139, 135, 124],
#         [146, 134, 127],
#         ...,
#         [142, 129, 113],
#         [144, 132, 109],
#         [145, 135, 115]],
#
#        [[142, 131, 111],
#         [137, 130, 122],
#         [151, 152, 130],
#         ...,
#         [148, 143, 123],
#         [139, 134, 109],
#         [142, 132, 112]]], dtype=uint8),
#         0],
#        [array([[[174, 157, 136],
#         [178, 165, 143],
#         [179, 172, 150],
#         ...,
#         [154, 138, 124],
#         [157, 141, 128],
#         [156, 140, 125]],
#
#        [[177, 160, 138],
#         [179, 167, 145],
#         [179, 172, 149],
#         ...,
#         [154, 137, 123],
#         [156, 138, 124],
#         [158, 140, 126]],
#
#        [[179, 163, 143],
#         [180, 170, 149],
#         [175, 171, 150],
#         ...,
#         [154, 137, 121],
#         [153, 135, 121],
#         [154, 136, 122]],
#
#        ...,
#
#        [[155, 157, 135],
#         [156, 155, 134],
#         [157, 155, 134],
#         ...,
#         [153, 138, 117],
#         [154, 139, 118],
#         [154, 139, 117]],
#
#        [[154, 156, 135],
#         [157, 156, 134],
#         [156, 156, 132],
#         ...,
#         [155, 141, 122],
#         [154, 140, 121],
#         [154, 140, 121]],
#
#        [[154, 156, 135],
#         [153, 155, 133],
#         [155, 155, 131],
#         ...,
#         [152, 141, 122],
#         [153, 142, 124],
#         [154, 143, 125]]], dtype=uint8),
#         0],
#        [array([[[157, 159, 158],
#         [159, 159, 161],
#         [158, 156, 160],
#         ...,
#         [160, 161, 156],
#         [161, 162, 157],
#         [161, 162, 156]],
#
#        [[157, 156, 161],
#         [158, 157, 162],
#         [159, 155, 161],
#         ...,
#         [157, 158, 153],
#         [158, 159, 153],
#         [159, 160, 153]],
#
#        [[154, 155, 159],
#         [156, 157, 161],
#         [161, 155, 163],
#         ...,
#         [157, 158, 153],
#         [157, 158, 151],
#         [157, 160, 149]],
#
#        ...,
#
#        [[155, 157, 156],
#         [156, 157, 156],
#         [154, 156, 154],
#         ...,
#         [151, 153, 152],
#         [152, 156, 156],
#         [152, 156, 157]],
#
#        [[152, 155, 154],
#         [154, 159, 153],
#         [154, 158, 151],
#         ...,
#         [150, 154, 153],
#         [153, 157, 156],
#         [152, 156, 156]],
#
#        [[143, 148, 150],
#         [146, 152, 149],
#         [147, 152, 147],
#         ...,
#         [152, 156, 155],
#         [153, 158, 155],
#         [149, 154, 150]]], dtype=uint8),
#         0],
#        [array([[[151, 135, 121],
#         [148, 131, 114],
#         [165, 170, 149],
#         ...,
#         [159, 145, 136],
#         [170, 168, 158],
#         [168, 173, 159]],
#
#        [[152, 136, 124],
#         [151, 140, 122],
#         [167, 169, 154],
#         ...,
#         [157, 141, 126],
#         [158, 143, 130],
#         [155, 138, 123]],
#
#        [[155, 139, 123],
#         [145, 136, 118],
#         [168, 172, 155],
#         ...,
#         [158, 140, 125],
#         [159, 141, 116],
#         [160, 142, 128]],
#
#        ...,
#
#        [[132, 123, 116],
#         [140, 136, 131],
#         [151, 154, 139],
#         ...,
#         [162, 166, 139],
#         [150, 137, 121],
#         [151, 149, 121]],
#
#        [[142, 127, 112],
#         [145, 128, 121],
#         [134, 130, 120],
#         ...,
#         [160, 164, 141],
#         [144, 135, 120],
#         [153, 143, 125]],
#
#        [[148, 142, 133],
#         [148, 138, 126],
#         [143, 131, 114],
#         ...,
#         [158, 161, 142],
#         [155, 155, 129],
#         [145, 134, 115]]], dtype=uint8),
#         0],
#        [array([[[147, 140, 141],
#         [146, 138, 136],
#         [142, 135, 134],
#         ...,
#         [158, 160, 155],
#         [158, 159, 153],
#         [157, 158, 152]],
#
#        [[148, 138, 142],
#         [144, 135, 137],
#         [141, 132, 134],
#         ...,
#         [157, 159, 154],
#         [158, 159, 154],
#         [158, 159, 154]],
#
#        [[150, 138, 144],
#         [146, 135, 140],
#         [143, 133, 137],
#         ...,
#         [158, 160, 157],
#         [158, 159, 157],
#         [158, 158, 157]],
#
#        ...,
#
#        [[158, 161, 159],
#         [158, 162, 160],
#         [158, 163, 161],
#         ...,
#         [156, 158, 153],
#         [156, 159, 152],
#         [156, 159, 152]],
#
#        [[157, 159, 158],
#         [156, 161, 160],
#         [158, 161, 160],
#         ...,
#         [157, 159, 154],
#         [157, 159, 153],
#         [157, 159, 153]],
#
#        [[156, 158, 157],
#         [154, 158, 157],
#         [155, 159, 158],
#         ...,
#         [158, 160, 155],
#         [159, 161, 156],
#         [159, 161, 156]]], dtype=uint8),
#         0],
#        [array([[[139, 120, 122],
#         [141, 121, 123],
#         [141, 122, 124],
#         ...,
#         [149, 130, 136],
#         [147, 131, 133],
#         [144, 128, 129]],
#
#        [[139, 123, 123],
#         [139, 121, 122],
#         [139, 120, 121],
#         ...,
#         [147, 130, 134],
#         [146, 131, 132],
#         [144, 128, 128]],
#
#        [[132, 120, 120],
#         [133, 121, 121],
#         [135, 121, 120],
#         ...,
#         [148, 130, 134],
#         [148, 130, 132],
#         [148, 129, 131]],
#
#        ...,
#
#        [[160, 164, 163],
#         [161, 165, 164],
#         [158, 163, 163],
#         ...,
#         [160, 167, 157],
#         [160, 165, 158],
#         [160, 165, 159]],
#
#        [[158, 162, 161],
#         [161, 165, 165],
#         [159, 164, 163],
#         ...,
#         [162, 168, 160],
#         [162, 167, 160],
#         [161, 166, 161]],
#
#        [[156, 160, 157],
#         [163, 167, 166],
#         [161, 166, 163],
#         ...,
#         [162, 167, 161],
#         [161, 166, 160],
#         [161, 165, 163]]], dtype=uint8),
#         0],
#        [array([[[119,  68, 144],
#         [119,  69, 143],
#         [118,  68, 139],
#         ...,
#         [168, 147, 126],
#         [168, 150, 125],
#         [168, 151, 125]],
#
#        [[117,  69, 136],
#         [122,  73, 137],
#         [123,  74, 138],
#         ...,
#         [170, 149, 123],
#         [169, 150, 121],
#         [169, 149, 122]],
#
#        [[123,  75, 138],
#         [124,  76, 135],
#         [125,  78, 137],
#         ...,
#         [166, 147, 119],
#         [165, 147, 120],
#         [166, 149, 123]],
#
#        ...,
#
#        [[161, 160, 140],
#         [164, 163, 143],
#         [162, 161, 140],
#         ...,
#         [152, 132, 111],
#         [151, 133, 111],
#         [151, 134, 112]],
#
#        [[162, 160, 142],
#         [164, 162, 144],
#         [163, 161, 144],
#         ...,
#         [153, 132, 111],
#         [154, 133, 112],
#         [155, 134, 113]],
#
#        [[165, 162, 145],
#         [165, 162, 146],
#         [164, 161, 147],
#         ...,
#         [155, 134, 112],
#         [156, 134, 113],
#         [157, 135, 114]]], dtype=uint8),
#         0],
#        [array([[[182, 172, 154],
#         [181, 173, 154],
#         [182, 174, 155],
#         ...,
#         [164, 142, 131],
#         [162, 142, 129],
#         [164, 145, 131]],
#
#        [[179, 174, 153],
#         [178, 175, 155],
#         [178, 175, 155],
#         ...,
#         [164, 141, 131],
#         [164, 142, 130],
#         [167, 144, 131]],
#
#        [[179, 175, 158],
#         [179, 174, 157],
#         [179, 174, 157],
#         ...,
#         [164, 139, 130],
#         [165, 141, 130],
#         [164, 140, 130]],
#
#        ...,
#
#        [[171, 169, 156],
#         [171, 169, 157],
#         [171, 169, 157],
#         ...,
#         [167, 146, 134],
#         [168, 144, 133],
#         [167, 143, 132]],
#
#        [[172, 170, 158],
#         [172, 169, 159],
#         [171, 168, 159],
#         ...,
#         [168, 147, 136],
#         [168, 146, 135],
#         [166, 144, 133]],
#
#        [[175, 171, 159],
#         [173, 169, 159],
#         [172, 168, 157],
#         ...,
#         [167, 147, 136],
#         [166, 147, 133],
#         [166, 144, 131]]], dtype=uint8),
#         0],
#        [array([[[138, 127, 109],
#         [136, 126, 108],
#         [140, 122, 107],
#         ...,
#         [140, 144, 126],
#         [139, 139, 124],
#         [138, 132, 110]],
#
#        [[138, 123, 105],
#         [139, 124, 109],
#         [136, 121, 105],
#         ...,
#         [140, 145, 122],
#         [137, 131, 103],
#         [140, 126, 110]],
#
#        [[134, 118, 104],
#         [141, 124, 105],
#         [139, 140, 116],
#         ...,
#         [142, 143, 122],
#         [136, 132, 106],
#         [143, 127, 111]],
#
#        ...,
#
#        [[128, 113, 114],
#         [124, 105, 121],
#         [131, 100, 120],
#         ...,
#         [137, 138, 106],
#         [134, 140, 114],
#         [131, 133, 109]],
#
#        [[120,  87, 114],
#         [123,  96, 107],
#         [126,  99, 112],
#         ...,
#         [127, 113,  89],
#         [128, 113,  90],
#         [127, 115, 103]],
#
#        [[127,  97, 112],
#         [121,  99, 111],
#         [126, 101, 111],
#         ...,
#         [127, 115,  94],
#         [131, 115,  91],
#         [132, 117,  94]]], dtype=uint8),
#         0],
#        [array([[[152, 140, 124],
#         [150, 142, 130],
#         [153, 142, 123],
#         ...,
#         [155, 149, 128],
#         [155, 143, 127],
#         [158, 148, 128]],
#
#        [[153, 145, 131],
#         [155, 144, 135],
#         [151, 143, 132],
#         ...,
#         [154, 148, 129],
#         [158, 149, 134],
#         [159, 147, 131]],
#
#        [[155, 143, 129],
#         [155, 145, 130],
#         [155, 147, 126],
#         ...,
#         [160, 148, 134],
#         [160, 148, 138],
#         [158, 150, 132]],
#
#        ...,
#
#        [[147, 148, 139],
#         [149, 151, 136],
#         [147, 149, 136],
#         ...,
#         [149, 152, 126],
#         [149, 151, 127],
#         [150, 153, 134]],
#
#        [[148, 150, 133],
#         [148, 149, 142],
#         [147, 150, 133],
#         ...,
#         [148, 151, 130],
#         [149, 151, 130],
#         [150, 152, 138]],
#
#        [[137, 139, 121],
#         [150, 150, 138],
#         [147, 151, 136],
#         ...,
#         [149, 150, 134],
#         [150, 154, 139],
#         [150, 153, 136]]], dtype=uint8),
#         0]], dtype=object)

# %% [markdown]
# We will now store the image arrays and their labels for each class (validation and training data) in separate arrays: x_train, y_train, x_val and y_val.

# %%
#data processing 

#define the empty arrays that we will use to store the categories (positive or negative, in integers) and the images in its array form, for training and validation data separately.
x_train = []
y_train = []
x_val = []
y_val = []

#store the image and its corresponding label in x_train and y_train respectively, for each image in the training data set
for image, label in training_data:
  x_train.append(image)
  y_train.append(label)

#store the image and its corresponding label in x_val and y_val respectively, for each image in the validation data set.
for image, label in validation_data:
  x_val.append(image)
  y_val.append(label)

# %%
# #data augmentation on the training data
# datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
#         zoom_range = 0.2, # Randomly zoom image 
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip = True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images


# datagen.fit(x_train)

# %% [markdown]
# ## Model Definition - with Deep Learning

# %% [markdown]
# We will define a Sequential model with 10 layers. The input shape will be 224 by 224, and is colored. We begin by normalizing our data.

# %%
# Normalize the data so that all images will have the same size.
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
#model definition
num_classes = 2 #there are 2 classes: one for positive and one for negative

model = Sequential()
model.add(Conv2D(16,3,padding="same", activation="relu", input_shape=(224,224,3)))
model.add(MaxPool2D())
model.add(Conv2D(16, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(num_classes))

# %% [markdown]
# We will now compile our model using the 'Adam' optimizer.

# %%
#compile our model
model.compile(optimizer = 'Adam', 
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics = ['accuracy'])

# %% [markdown]
# Here is the summary of our model. We have 6,434,962 parameters in total in our model, and all of them can be trained.

# %%
model.summary() #see what we have in our model
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        9280
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               6422656
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 6,434,962
# Trainable params: 6,434,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training - with Deep Learning
#
# We will now train our model

# %%
epochs = 12
batch_size = 32
history = model.fit(x_train,y_train, batch_size= batch_size, epochs = epochs , validation_data = (x_val, y_val)) #train model
# Out:
# Epoch 1/12
# 4/4 [==============================] - 33s 3s/step - loss: 0.3570 - accuracy: 0.5735 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 6/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 7/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 8/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 9/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 10/12
# 4/4 [==============================] - 9s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 11/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 12/12
# 4/4 [==============================] - 10s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
score = model.evaluate(x_val, y_val, verbose = 0)

# %%
print("accuracy: ", score[1])
# Out:
# accuracy:  1.0

# %% [markdown]
# ## Model Definition - with Supervised Model

# %%
import pandas as pd
from skimage.transform import resize
from skimage.io import imread

image_data_flattened =[] #input array
target_array = [] #output array
data_directory_training = "./input/training"

for i in labels:
    path_training = os.path.join(data_directory_training, i)
    for img in os.listdir(path_training):
        img_array = imread(os.path.join(path_training, img))
        img_resized = resize(img_array, (224,224,3)) #resize input image
        image_data_flattened.append(img_resized.flatten()) #flatten image
        target_array.append(labels.index(i))
    print(f'loaded category: {i} successfully')

flattened_data = np.array(image_data_flattened)
target_data = np.array(target_array)

df = pd.DataFrame(flattened_data)
df['Target'] = target_data #add column for target (the labels)
x_train_supervised = df.iloc[:,:-1] #input
y_train_supervised = df.iloc[:,-1] #output
# Out:
# loaded category: positive successfully
# loaded category: negative successfully

# %%
#validation data
image_data_flattened_v =[] #input array
target_array_v = [] #output array
data_dir_validation = "./input/validation"

for i in labels:
    path_validation = os.path.join(data_dir_validation, i)
    for img in os.listdir(path_validation):
        img_array = imread(os.path.join(path_validation, img))
        img_resized = resize(img_array, (224,224,3)) #resize input image
        image_data_flattened_v.append(img_resized.flatten()) #flatten image
        target_array_v.append(labels.index(i))
    print(f'loaded category: {i} successfully')

flattened_data_v = np.array(image_data_flattened_v)
target_data_v = np.array(target_array_v)

df_v = pd.DataFrame(flattened_data_v)
df_v['Target'] = target_data_v #add column for target (the labels)
x_val_supervised = df_v.iloc[:,:-1] #input
y_val_supervised = df_v.iloc[:,-1] #output
# Out:
# loaded category: positive successfully
# loaded category: negative successfully

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV

param_grid={'C':[0.1,1,10,100],'gamma':[0.0001,0.001,0.1,1],'kernel':['rbf','poly']}

svc=svm.SVC(probability=True)
model_supervised =GridSearchCV(svc,param_grid)

# %%
#train the supervised model

model_supervised.fit(x_train_supervised, y_train_supervised)

# %%
#test the supervised model
y_predicted =model_supervised.predict(x_val_supervised)
print("The predicted Data is :")
print(y_predicted)
print("The actual data is:")
print(np.array(y_val_supervised))
print(f"The model is {accuracy_score(y_predicted,y_val_supervised)*100}% accurate")
